# %%
import datetime
import pandas as pd
with open("../.env") as fo:
    github_token = fo.read()[:-1]
session_start = datetime.datetime.utcnow()
print(session_start)
# Out:
# 2019-07-22 21:14:09.714877

# %% [markdown]
# ## Github API v4 GraphQL
# Using the requests module as suggested in the top answer at [How to consume the Github GraphQL API using Python?](https://stackoverflow.com/questions/45957784/how-to-consume-the-github-graphql-api-using-python)

# %%
import requests
github_url = 'https://api.github.com/graphql'
github_headers = {'Authorization': f"token {github_token}"}
query = {
    'query': """{
        repository(owner:"LD4P", name:"sinopia_editor") {
          issues(states:OPEN, first:100) {
            edges {
              node {
                title
                url
                number
              }
            }
          } 
       }
    }
    """
}
result = requests.post(url=github_url, json=query, headers=github_headers)

# %%
def issues_query(state='OPEN', first=100):
    query = {
        'query': """{{
            repository(owner:"LD4P", name:"sinopia_editor") {{
              issues(first:{first}) {{
                pageInfo {{
                    startCursor
                    hasNextPage
                    endCursor
                }}
                edges {{
                  node {{
                    title
                    url
                    number
                    createdAt
                    closedAt
                    projectCards(first:5) {{
                      edges {{
                          node {{
                              project {{
                                      name
                                      number
                              }}
                              state
                          }}
                      }}
                    }}
                    participants(first:10) {{
                        edges {{
                            node {{
                                login
                            }}
                        }}
                    }}
                    state
                  }}
                }}
              }} 
           }}
        }}
    """.format(state=state, first=first)
    }
    result = requests.post(url=github_url, json=query, headers=github_headers)
    return result.json()
    
def commits_query(repo):
    query = {
        "query": """{{
            repository(owner:"LD4P", name:"{repo}") {{
                refs(refPrefix: "refs/master/"){{
                    totalCount
                }}
        
            }}
        }}
        """.format(repo=repo)
    }
    result = requests.post(url=github_url, json=query, headers=github_headers)
    return result.json()

# %%
first_issues = issues_query()

# %%
first_issues
# Out:
# {'data': {'repository': {'issues': {'pageInfo': {'startCursor': 'Y3Vyc29yOnYyOpHOFbQ6kg==',
#      'hasNextPage': True,
#      'endCursor': 'Y3Vyc29yOnYyOpHOFrpukA=='},
#     'edges': [{'node': {'title': 'testing suite for sinopia_editor ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/1',
#        'number': 1,
#        'createdAt': '2018-09-26T17:24:27Z',
#        'closedAt': '2018-09-27T22:55:09Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'mejackreed'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Code syntax/style checking w ESLint for sinopia_editor',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/2',
#        'number': 2,
#        'createdAt': '2018-09-26T17:30:33Z',
#        'closedAt': '2018-09-26T23:01:05Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'CI hooked up for sinopia_editor',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/3',
#        'number': 3,
#        'createdAt': '2018-09-26T17:34:42Z',
#        'closedAt': '2018-09-28T14:59:47Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'instructions / setup to use localstack for aws mocking',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/4',
#        'number': 4,
#        'createdAt': '2018-09-26T17:35:59Z',
#        'closedAt': '2019-03-12T16:39:19Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'configuration supports node.js best-practices',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/5',
#        'number': 5,
#        'createdAt': '2018-09-26T17:38:08Z',
#        'closedAt': None,
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'decompose bfe.js into separate code components',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/6',
#        'number': 6,
#        'createdAt': '2018-09-26T17:40:50Z',
#        'closedAt': '2018-11-20T21:35:29Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Authentication wrapper for BFE',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/7',
#        'number': 7,
#        'createdAt': '2018-09-26T17:42:41Z',
#        'closedAt': '2019-03-13T22:12:29Z',
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Wrap RDF javascript as NPM package',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/8',
#        'number': 8,
#        'createdAt': '2018-09-26T17:44:00Z',
#        'closedAt': '2019-03-13T22:12:52Z',
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Grunt default task problems',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/9',
#        'number': 9,
#        'createdAt': '2018-09-26T17:48:17Z',
#        'closedAt': '2018-09-26T22:14:43Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Use QA instead of `lookups` array',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/10',
#        'number': 10,
#        'createdAt': '2018-09-26T17:50:32Z',
#        'closedAt': '2018-09-26T19:20:21Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'kirkhess'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': "Isn't grunt a dev dependency, not a prod dependency?",
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/13',
#        'number': 13,
#        'createdAt': '2018-09-26T23:47:53Z',
#        'closedAt': '2018-09-28T16:51:11Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Code coverage stats part of CI builds (requires #3)',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/14',
#        'number': 14,
#        'createdAt': '2018-09-26T23:55:36Z',
#        'closedAt': '2018-10-04T00:34:16Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'test doing something and passing in CI',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/16',
#        'number': 16,
#        'createdAt': '2018-09-27T22:24:29Z',
#        'closedAt': '2018-10-02T19:05:20Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'tests for when no profile is loaded (BFF)',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/17',
#        'number': 17,
#        'createdAt': '2018-09-27T22:29:48Z',
#        'closedAt': '2019-02-25T17:51:36Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'tests for loading profile to use in BFF',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/18',
#        'number': 18,
#        'createdAt': '2018-09-27T22:31:21Z',
#        'closedAt': '2019-02-25T17:51:20Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'CI:  run tests via grunt instead of npm?',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/19',
#        'number': 19,
#        'createdAt': '2018-09-28T00:20:08Z',
#        'closedAt': '2018-09-28T22:18:38Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Update URLs in package.json',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/21',
#        'number': 21,
#        'createdAt': '2018-09-28T05:41:41Z',
#        'closedAt': '2018-09-28T15:21:14Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': "npm serve-static isn't used?",
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/25',
#        'number': 25,
#        'createdAt': '2018-09-28T17:07:44Z',
#        'closedAt': '2018-10-31T22:36:24Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'atz'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'CI runs linter',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/26',
#        'number': 26,
#        'createdAt': '2018-09-28T17:51:17Z',
#        'closedAt': '2018-10-03T22:30:40Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'linter runs cleanly',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/27',
#        'number': 27,
#        'createdAt': '2018-09-28T17:52:57Z',
#        'closedAt': '2018-10-03T22:30:40Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Remove grunt ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/28',
#        'number': 28,
#        'createdAt': '2018-09-28T22:19:49Z',
#        'closedAt': '2018-11-16T17:26:43Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'atz'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'SaravShah'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'use jest-puppeteer for integration tests',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/29',
#        'number': 29,
#        'createdAt': '2018-09-28T22:22:51Z',
#        'closedAt': '2018-10-02T19:05:20Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'run editor (and tests) entirely out of builds or dist directory',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/30',
#        'number': 30,
#        'createdAt': '2018-10-01T23:50:14Z',
#        'closedAt': '2018-11-20T21:35:07Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'do we really need ALL the libraries installed by .circleci/setup_puppeteer.sh',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/32',
#        'number': 32,
#        'createdAt': '2018-10-02T17:59:22Z',
#        'closedAt': '2018-10-10T16:09:11Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'have an easy way to run tests, etc. as ci does',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/34',
#        'number': 34,
#        'createdAt': '2018-10-02T22:56:45Z',
#        'closedAt': '2019-01-11T17:57:47Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'circleci gets plato artifacts',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/37',
#        'number': 37,
#        'createdAt': '2018-10-03T18:14:33Z',
#        'closedAt': '2018-10-04T15:42:19Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'add static/config.js to coverage, eslint',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/38',
#        'number': 38,
#        'createdAt': '2018-10-03T18:17:11Z',
#        'closedAt': '2018-10-04T00:34:06Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'add CSS linter ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/44',
#        'number': 44,
#        'createdAt': '2018-10-10T17:43:33Z',
#        'closedAt': '2018-10-11T23:23:31Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'generate eslint todo list with eslint-takeoff',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/45',
#        'number': 45,
#        'createdAt': '2018-10-10T17:44:34Z',
#        'closedAt': '2018-10-11T14:46:10Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'should eslintrc get globals?',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/46',
#        'number': 46,
#        'createdAt': '2018-10-10T17:45:20Z',
#        'closedAt': '2018-10-16T17:22:05Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'instructions for running app locally with profiles available in README',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/47',
#        'number': 47,
#        'createdAt': '2018-10-10T21:04:38Z',
#        'closedAt': '2019-03-12T16:36:09Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'testing fixtures needed',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/48',
#        'number': 48,
#        'createdAt': '2018-10-10T21:08:19Z',
#        'closedAt': '2018-10-12T15:41:28Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'test: able to run app in jest-puppeteer with profile(s) loaded',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/49',
#        'number': 49,
#        'createdAt': '2018-10-10T21:12:33Z',
#        'closedAt': '2018-10-16T17:22:05Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'tests: intercept verso calls and return profile(s) from fixtures',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/50',
#        'number': 50,
#        'createdAt': '2018-10-10T21:16:48Z',
#        'closedAt': '2018-11-07T22:58:55Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'tests: rename basic.test.js',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/51',
#        'number': 51,
#        'createdAt': '2018-10-10T21:19:35Z',
#        'closedAt': '2018-10-11T23:53:59Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests:  displayed menu of startingPoints ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/52',
#        'number': 52,
#        'createdAt': '2018-10-10T21:23:47Z',
#        'closedAt': '2018-10-16T22:04:34Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests: startingPoints menu works',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/53',
#        'number': 53,
#        'createdAt': '2018-10-10T21:32:07Z',
#        'closedAt': '2019-03-12T16:31:03Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests: text input fields',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/54',
#        'number': 54,
#        'createdAt': '2018-10-10T21:40:00Z',
#        'closedAt': '2019-03-12T16:36:31Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests: modal input fields',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/55',
#        'number': 55,
#        'createdAt': '2018-10-10T21:46:03Z',
#        'closedAt': '2019-03-12T16:36:46Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests: Preview button',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/56',
#        'number': 56,
#        'createdAt': '2018-10-10T21:52:41Z',
#        'closedAt': '2019-07-13T05:33:33Z',
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'jcoyne'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests:  preview part 2:  modal input ends up in json',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/57',
#        'number': 57,
#        'createdAt': '2018-10-10T21:56:28Z',
#        'closedAt': '2019-03-12T16:37:08Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests: lookup functionality',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/58',
#        'number': 58,
#        'createdAt': '2018-10-10T22:00:23Z',
#        'closedAt': '2019-03-12T16:38:11Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'browse tab tests',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/59',
#        'number': 59,
#        'createdAt': '2018-10-10T22:04:28Z',
#        'closedAt': '2018-10-12T17:30:57Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'create docker image to run sinopia editor',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/62',
#        'number': 62,
#        'createdAt': '2018-10-11T00:40:32Z',
#        'closedAt': '2019-03-12T16:39:35Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Rename server-bfe.js to server.js',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/66',
#        'number': 66,
#        'createdAt': '2018-10-12T15:49:49Z',
#        'closedAt': '2018-11-02T19:47:13Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'refactor config and index.html very slightly to make BFF more testable',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/70',
#        'number': 70,
#        'createdAt': '2018-10-16T00:44:10Z',
#        'closedAt': '2018-11-29T23:28:01Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'refactor config - split into code and data.',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/71',
#        'number': 71,
#        'createdAt': '2018-10-16T00:46:29Z',
#        'closedAt': '2019-03-12T16:42:34Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'refactor: dry up tests by making functions/matchers avail',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/75',
#        'number': 75,
#        'createdAt': '2018-10-18T18:15:17Z',
#        'closedAt': '2019-06-25T19:07:18Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'refactor: use page.waitForXXX instead of waitFor(1000)',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/76',
#        'number': 76,
#        'createdAt': '2018-10-18T18:18:05Z',
#        'closedAt': '2019-06-25T19:06:08Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests: functionality of cancel button',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/77',
#        'number': 77,
#        'createdAt': '2018-10-18T18:20:00Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'editor tab tests: functionality of clone instance button',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/78',
#        'number': 78,
#        'createdAt': '2018-10-18T18:22:33Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'tests - able to load multiple profiles',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/79',
#        'number': 79,
#        'createdAt': '2018-10-18T18:35:02Z',
#        'closedAt': '2019-03-12T16:31:29Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor tab tests:  functionality of controlled vocabs',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/80',
#        'number': 80,
#        'createdAt': '2018-10-19T20:51:41Z',
#        'closedAt': '2019-03-12T16:30:11Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Sinopia Homepage Process',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/82',
#        'number': 82,
#        'createdAt': '2018-10-22T23:37:45Z',
#        'closedAt': '2018-11-20T01:25:44Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'michelleif'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Profile Editor alignment of action "buttons" is wonky',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/84',
#        'number': 84,
#        'createdAt': '2018-10-25T18:17:02Z',
#        'closedAt': '2018-10-25T18:18:27Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'List Items in NewsPanel.jsx can be own ReactComponent',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/88',
#        'number': 88,
#        'createdAt': '2018-10-31T17:00:47Z',
#        'closedAt': '2018-11-05T18:53:17Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Finish React Components for Homepage',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/90',
#        'number': 90,
#        'createdAt': '2018-11-01T21:30:34Z',
#        'closedAt': '2018-11-08T20:23:00Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Setup AWS for homepage deployment',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/91',
#        'number': 91,
#        'createdAt': '2018-11-01T21:33:37Z',
#        'closedAt': '2018-11-09T17:24:44Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Can profile parsers and management be decomposed into separate components?',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/92',
#        'number': 92,
#        'createdAt': '2018-11-01T22:25:53Z',
#        'closedAt': '2018-11-12T16:48:05Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Initial code structure for BFF',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/93',
#        'number': 93,
#        'createdAt': '2018-11-01T22:31:28Z',
#        'closedAt': '2018-11-20T21:47:51Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Tests and support structures for necessary for new components in BFE',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/94',
#        'number': 94,
#        'createdAt': '2018-11-01T22:36:37Z',
#        'closedAt': '2018-11-12T18:51:46Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Implement React Router',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/96',
#        'number': 96,
#        'createdAt': '2018-11-02T17:27:40Z',
#        'closedAt': '2018-11-07T23:26:25Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Update README for react homepage',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/105',
#        'number': 105,
#        'createdAt': '2018-11-05T19:02:11Z',
#        'closedAt': '2018-11-07T01:19:23Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'atz'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Use dist directory for Circle-CI',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/106',
#        'number': 106,
#        'createdAt': '2018-11-05T19:16:44Z',
#        'closedAt': '2018-11-05T21:18:05Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Create Sinopia internal Header',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/111',
#        'number': 111,
#        'createdAt': '2018-11-05T23:48:56Z',
#        'closedAt': '2018-11-10T00:11:46Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'SaravShah'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Separate CSS for BFF Editor',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/112',
#        'number': 112,
#        'createdAt': '2018-11-05T23:59:30Z',
#        'closedAt': None,
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Create Browse, Import Resource Template, and Editor Tab stubs',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/113',
#        'number': 113,
#        'createdAt': '2018-11-06T00:12:50Z',
#        'closedAt': '2019-02-20T17:11:08Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}},
#          {'node': {'login': 'SaravShah'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Update LICENSE to Apache 2.0',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/114',
#        'number': 114,
#        'createdAt': '2018-11-06T00:25:15Z',
#        'closedAt': '2018-11-15T23:58:05Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Integration Tests for React Components in Sinopia ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/115',
#        'number': 115,
#        'createdAt': '2018-11-06T18:56:13Z',
#        'closedAt': '2019-01-22T18:49:47Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'is it possible for "hot" module to only happen in some environments',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/116',
#        'number': 116,
#        'createdAt': '2018-11-06T23:40:13Z',
#        'closedAt': '2019-03-12T16:28:33Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'editor beginnings: ResourceTemplate and PropertyTemplate containers',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/122',
#        'number': 122,
#        'createdAt': '2018-11-08T23:05:20Z',
#        'closedAt': '2018-11-09T19:26:09Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'parse ValueConstraints from PropertyTemplates',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/123',
#        'number': 123,
#        'createdAt': '2018-11-08T23:06:21Z',
#        'closedAt': '2018-11-15T02:52:46Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Modal for nested ResourceTemplate',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/124',
#        'number': 124,
#        'createdAt': '2018-11-08T23:09:26Z',
#        'closedAt': '2018-12-19T00:01:56Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'spoof calls to get resource template from (LDP) storage',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/125',
#        'number': 125,
#        'createdAt': '2018-11-08T23:13:14Z',
#        'closedAt': '2018-11-16T01:20:24Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Modal triggering another Modal',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/126',
#        'number': 126,
#        'createdAt': '2018-11-08T23:13:55Z',
#        'closedAt': '2018-12-19T00:01:31Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'actual form fields from PropertyTemplate',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/127',
#        'number': 127,
#        'createdAt': '2018-11-08T23:17:03Z',
#        'closedAt': '2018-11-21T17:57:31Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'SaravShah'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'input fields  with controlled vocabularies implemented',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/128',
#        'number': 128,
#        'createdAt': '2018-11-08T23:18:04Z',
#        'closedAt': '2018-11-29T18:01:46Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'ReactJS tests should not be using .toBeDefined()',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/129',
#        'number': 129,
#        'createdAt': '2018-11-09T01:51:12Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'ResourceTemplate form.id need to be unique',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/130',
#        'number': 130,
#        'createdAt': '2018-11-09T01:51:32Z',
#        'closedAt': '2019-03-12T16:28:14Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'enzyme tests using "mount" need to unmount',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/131',
#        'number': 131,
#        'createdAt': '2018-11-09T02:14:32Z',
#        'closedAt': '2018-11-16T01:38:46Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'add tests for PropertiesWrapper',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/132',
#        'number': 132,
#        'createdAt': '2018-11-09T02:27:25Z',
#        'closedAt': '2018-11-15T18:06:45Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'ResourceTemplate form: add submit and cancel buttons',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/134',
#        'number': 134,
#        'createdAt': '2018-11-09T02:41:31Z',
#        'closedAt': '2019-06-04T22:38:57Z',
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Resource Template shows info about id',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/135',
#        'number': 135,
#        'createdAt': '2018-11-09T02:45:36Z',
#        'closedAt': None,
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Resource Template "clone instance" button',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/136',
#        'number': 136,
#        'createdAt': '2018-11-09T02:48:35Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'EditorTitle React Component',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/137',
#        'number': 137,
#        'createdAt': '2018-11-09T17:22:05Z',
#        'closedAt': '2019-01-31T20:17:24Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'SaravShah'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Remove images from bundle.js',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/138',
#        'number': 138,
#        'createdAt': '2018-11-09T17:40:28Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Move dottedBorder, dashedBorder to css',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/139',
#        'number': 139,
#        'createdAt': '2018-11-09T19:25:25Z',
#        'closedAt': '2019-03-13T22:06:22Z',
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Investigating making a routes javascript module. ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/141',
#        'number': 141,
#        'createdAt': '2018-11-09T21:37:50Z',
#        'closedAt': '2019-03-11T23:40:29Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Add a URI as the Object of statement when a lookup isn’t available or able to retrieve a recently created entity in an external data source.',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/142',
#        'number': 142,
#        'createdAt': '2018-11-09T21:41:32Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'sfolsom'}},
#          {'node': {'login': 'michelleif'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Sinopia.io is not displaying on Internet Explorer',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/144',
#        'number': 144,
#        'createdAt': '2018-11-10T00:06:41Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'michelleif'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Move EditorHeader.jsx into subfolder editor/',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/145',
#        'number': 145,
#        'createdAt': '2018-11-12T05:47:50Z',
#        'closedAt': '2018-11-16T16:55:51Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'create "Starting Points" component as placeholder',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/147',
#        'number': 147,
#        'createdAt': '2018-11-12T22:10:14Z',
#        'closedAt': '2018-11-15T23:57:25Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'script to run js compile for any changed source files before running tests',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/149',
#        'number': 149,
#        'createdAt': '2018-11-13T01:24:09Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'BFE blank node generation when adding ',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/151',
#        'number': 151,
#        'createdAt': '2018-11-14T19:20:38Z',
#        'closedAt': '2019-07-12T17:14:51Z',
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle One',
#             'number': 3},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'hudajkhan'}},
#          {'node': {'login': 'michelleif'}},
#          {'node': {'login': 'zimeon'}},
#          {'node': {'login': 'kirkhess'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'How do we model nested resourceTemplates vs. resourceTemplates that are valueConstraints?',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/152',
#        'number': 152,
#        'createdAt': '2018-11-14T20:33:57Z',
#        'closedAt': '2019-03-12T01:07:03Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jgreben'}},
#          {'node': {'login': 'cmharlow'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Directly loading editor route causes error',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/153',
#        'number': 153,
#        'createdAt': '2018-11-14T22:31:06Z',
#        'closedAt': '2018-11-15T18:10:55Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'jermnelson'}},
#          {'node': {'login': 'ndushay'}},
#          {'node': {'login': 'SaravShah'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'add global js ifEmpty() function',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/158',
#        'number': 158,
#        'createdAt': '2018-11-15T18:56:05Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'ndushay'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Update README w/ more descriptive docker steps',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/159',
#        'number': 159,
#        'createdAt': '2018-11-15T19:18:36Z',
#        'closedAt': '2018-11-15T20:52:23Z',
#        'projectCards': {'edges': []},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'jermnelson'}}]},
#        'state': 'CLOSED'}},
#      {'node': {'title': 'Sinopia on header does not display Copperlight Gothic font on Safari',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/160',
#        'number': 160,
#        'createdAt': '2018-11-15T19:53:33Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}},
#      {'node': {'title': 'Fix CSS so homepage is dynamic',
#        'url': 'https://github.com/LD4P/sinopia_editor/issues/161',
#        'number': 161,
#        'createdAt': '2018-11-15T19:59:18Z',
#        'closedAt': None,
#        'projectCards': {'edges': [{'node': {'project': {'name': 'Sinopia Work-Cycle Two',
#             'number': 1},
#            'state': 'CONTENT_ONLY'}}]},
#        'participants': {'edges': [{'node': {'login': 'SaravShah'}},
#          {'node': {'login': 'jgreben'}},
#          {'node': {'login': 'michelleif'}}]},
#        'state': 'OPEN'}}]}}}}

# %%
result = commits_query("sinopia_editor")
print(result)
# Out:
# {'data': {'repository': {'refs': {'totalCount': 0}}}}

# %%
import os, sys

# %%
os.path.abspath('.')
sys.path.append('/Users/jpnelson/2019/project-notebooks/')
import src.sinopia.github as sinopia
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-235-985488b6d80e> in <module>
#       1 os.path.abspath('.')
#       2 sys.path.append('/Users/jpnelson/2019/project-notebooks/')
# ----> 3 import src.sinopia.github as sinopia
#
# ~/2019/project-notebooks/src/sinopia/github.py in <module>
#       6
#       7 GITHUB_URL = 'https://api.github.com/graphql'
# ----> 8 with open('../../.env') as fo:
#       9     GITHUB_HEADERS = {'Authorization': f"token {fo.read()}"}
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../.env'

# %%
dir(sinopia)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %% [markdown]
# ## Github API v3
# Using the [PyGithub](https://pygithub.readthedocs.io/en/latest/) package for metrics generation on the Sinopia project. current focus is on the `sinopia_editor` repository.

# %%
from github import Github

g = Github(github_token)

sinopia_editor = g.get_repo("LD4P/sinopia_editor")
open_issues = sinopia_editor.get_issues(state='open')
closed_issues = sinopia_editor.get_issues(state='closed')

# %%
print(f"## Session At {session_start}\nopen issues: {open_issues.totalCount}, closed: {closed_issues.totalCount}")
# Out:
# ## Session At 2019-07-22 21:14:09.714877
# open issues: 83, closed: 942

# %%
closed_issues[0].created_at
# Out:
# datetime.datetime(2019, 7, 19, 20, 15, 41)

# %%
def v3_closed_issues_date_frame(repo):
    closed_issues = repo.get_issues(state='closed')
    created_series, closed_series = {}, {}
    for row in closed_issues:
        created_series[row.number] =  row.created_at
        closed_series[row.number] = row.closed_at
    date_data_frame = pd.DataFrame({ "created": created_series,
                                  "closed": closed_series })
    date_data_frame["elasped"] = date_data_frame["closed"] -  date_data_frame["created"]
    return date_data_frame

def v3_filter_issues(repo, func=closed_issues_date_frame, since=None):
    data_frame = func(repo)
    if since is None:
        closed_issues = data_frame
        since = closed_issues[0]['created']
    else:
        start = pd.Timestamp(since)
        filter_mask = data_frame['created'] > start
        closed_issues = data_frame[filter_mask]
    return closed_issues

def v4_closed_issues_report(data_frame):
    since = data_frame['created'][data_frame['created'].index[0]]
    print(f"## Statistics on Closed Issues from {since}")
    print(f"- **Total**: {len(data_frame)}")
    print(f"- **Mean**: {data_frame['elasped'].mean()}")
    print(f"- **Median**: {data_frame['elasped'].median()}"), 
    print(f"- **Maxiumum number of elasped time**: {date_data_frame['elasped'].max()}")
    print(f"- **Fastest elasped time**: {date_data_frame['elasped'].min()}")

# %%
def v4_open_issues_data_frame(repo):
    open_issues = repo.get_issues(state='open')
    titles, created, state = {}, {}, {}
    for issue in open_issues:
        titles[issue.number] = issue.title
        created[issue.number] = issue.created_at
        state[issue.number] = issue.state
    data_frame = pd.DataFrame({ "titles": titles, "created": created, "state": state})
    return data_frame

# %% [markdown]
# ## Session At 2019-07-19 17:51:21.177430
# open issues: 77, closed: 935

# %% [markdown]
# ## Session At 2019-07-18 16:26:17.849673
# open issues: 81, closed: 920

# %%
sprint_closed = filter_issues(sinopia_editor, since=datetime.datetime(2019,7,3))

# %%
closed_issues[0].state
# Out:
# 'closed'

# %%
sprint_open = filter_issues(sinopia_editor, func=open_issues_data_frame, since=datetime.datetime(2019,7,3))

# %%
dir(open_issues[3])
# Out:
# ['CHECK_AFTER_INIT_FLAG',
#  '_CompletableGithubObject__complete',
#  '_CompletableGithubObject__completed',
#  '_GithubObject__makeSimpleAttribute',
#  '_GithubObject__makeSimpleListAttribute',
#  '_GithubObject__makeTransformedAttribute',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_assignee',
#  '_assignees',
#  '_body',
#  '_closed_at',
#  '_closed_by',
#  '_comments',
#  '_comments_url',
#  '_completeIfNeeded',
#  '_completeIfNotSet',
#  '_created_at',
#  '_events_url',
#  '_headers',
#  '_html_url',
#  '_id',
#  '_identity',
#  '_initAttributes',
#  '_labels',
#  '_labels_url',
#  '_makeBoolAttribute',
#  '_makeClassAttribute',
#  '_makeDatetimeAttribute',
#  '_makeDictAttribute',
#  '_makeDictOfStringsToClassesAttribute',
#  '_makeIntAttribute',
#  '_makeListOfClassesAttribute',
#  '_makeListOfDictsAttribute',
#  '_makeListOfIntsAttribute',
#  '_makeListOfListOfStringsAttribute',
#  '_makeListOfStringsAttribute',
#  '_makeStringAttribute',
#  '_makeTimestampAttribute',
#  '_milestone',
#  '_number',
#  '_parentUrl',
#  '_pull_request',
#  '_rawData',
#  '_repository',
#  '_requester',
#  '_state',
#  '_storeAndUseAttributes',
#  '_title',
#  '_updated_at',
#  '_url',
#  '_useAttributes',
#  '_user',
#  'add_to_assignees',
#  'add_to_labels',
#  'as_pull_request',
#  'assignee',
#  'assignees',
#  'body',
#  'closed_at',
#  'closed_by',
#  'comments',
#  'comments_url',
#  'create_comment',
#  'create_reaction',
#  'created_at',
#  'delete_labels',
#  'edit',
#  'etag',
#  'events_url',
#  'get__repr__',
#  'get_comment',
#  'get_comments',
#  'get_events',
#  'get_labels',
#  'get_reactions',
#  'html_url',
#  'id',
#  'labels',
#  'labels_url',
#  'last_modified',
#  'milestone',
#  'number',
#  'pull_request',
#  'raw_data',
#  'raw_headers',
#  'remove_from_assignees',
#  'remove_from_labels',
#  'repository',
#  'setCheckAfterInitFlag',
#  'set_labels',
#  'state',
#  'title',
#  'update',
#  'updated_at',
#  'url',
#  'user']

# %% [markdown]
# ## Current Session At 2019-07-18 16:26:17.849673
# open issues: 83, closed: 918

# %%
sprint_closed_df = closed_issues(sinopia_editor, since=datetime.datetime(2019, 7, 3))

# 970 2019-07-16 19:28:09 2019-07-16 20:55:50   0 days 01:27:41
# 972 2019-07-16 20:19:41 2019-07-17 14:57:16   0 days 18:37:35
# 973 2019-07-16 20:53:18 2019-07-17 18:05:51   0 days 21:12:33
# 974 2019-07-16 21:13:13 2019-07-16 21:48:03   0 days 00:34:50
# 975 2019-07-17 10:32:25 2019-07-17 17:16:04   0 days 06:43:39
# 977 2019-07-17 15:56:34 2019-07-17 16:25:45   0 days 00:29:11
# 978 2019-07-17 16:50:53 2019-07-17 18:05:51   0 days 01:14:58
# 980 2019-07-17 16:56:49 2019-07-17 17:12:47   0 days 00:15:58
#
# [895 rows x 3 columns]

# %%
# Out:
# ## Statistics on Closed Issues at 2019-07-17 18:25:09.812405
# - **Mean**: 15 days 16:19:16.442458
# - **Median**: 0 days 21:37:39
# - **Maxiumum number of elasped time**: 335 days 15:05:14
# - **Fastest elasped time**: 0 days 00:00:24

# %% [markdown]
# ## Statistics on Closed Issues at 2019-07-17 18:25:09.812405
# - **Mean**: 15 days 16:19:16.442458
# - **Median**: 0 days 21:37:39
# - **Maxiumum number of elasped time**: 335 days 15:05:14
# - **Fastest elasped time**: 0 days 00:00:24

# %%
all_commits = sinopia_editor.get_commits()

# %%
print(all_commits.totalCount)
# Out:
# 1946

# %%
status_series, committer_series, last_modified_series = {},{},{}
for row in all_commits:
    status_series[row.sha] = row.get_combined_status().state
    committer_series[row.sha] = row.committer.login
    last_modified_series[row.sha] = row.last_modified
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1048                   self.__class__)
# -> 1049             return self.read(nbytes, buffer)
#    1050         else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     907             if buffer is not None:
# --> 908                 return self._sslobj.read(len, buffer)
#     909             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/2019/py3-env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 386             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     387             raise
#
# ~/2019/py3-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     305         if isinstance(err, SocketTimeout):
# --> 306             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     307
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.github.com', port=443): Read timed out. (read timeout=15)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-17-f1117a2fd2e8> in <module>
#       1 status_series, committer_series, last_modified_series = {},{},{}
#       2 for row in all_commits:
# ----> 3     status_series[row.sha] = row.get_combined_status().state
#       4     committer_series[row.sha] = row.committer.login
#       5     last_modified_series[row.sha] = row.last_modified
#
# ~/2019/py3-env/lib/python3.7/site-packages/github/Commit.py in get_combined_status(self)
#     222         headers, data = self._requester.requestJsonAndCheck(
#     223             "GET",
# --> 224             self.url + "/status"
#     225         )
#     226         return github.CommitCombinedStatus.CommitCombinedStatus(self._requester, headers, data, completed=True)
#
# ~/2019/py3-env/lib/python3.7/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     262
#     263     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 264         return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#     265
#     266     def requestMultipartAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#
# ~/2019/py3-env/lib/python3.7/site-packages/github/Requester.py in requestJson(self, verb, url, parameters, headers, input, cnx)
#     322             return "application/json", json.dumps(input)
#     323
# --> 324         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     325
#     326     def requestMultipart(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
#
# ~/2019/py3-env/lib/python3.7/site-packages/github/Requester.py in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     375         self.NEW_DEBUG_FRAME(requestHeaders)
#     376
# --> 377         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     378
#     379         if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#
# ~/2019/py3-env/lib/python3.7/site-packages/github/Requester.py in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     399             requestHeaders
#     400         )
# --> 401         response = cnx.getresponse()
#     402
#     403         status = response.status
#
# ~/2019/py3-env/lib/python3.7/site-packages/github/Requester.py in getresponse(self)
#     107         verb = getattr(self.session, self.verb.lower())
#     108         url = "%s://%s:%s%s" % (self.protocol, self.host, self.port, self.url)
# --> 109         r = verb(url, headers=self.headers, data=self.input, timeout=self.timeout, verify=self.verify, allow_redirects=False)
#     110         return RequestsResponse(r)
#     111
#
# ~/2019/py3-env/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~/2019/py3-env/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/2019/py3-env/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/2019/py3-env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='api.github.com', port=443): Read timed out. (read timeout=15)

# %%
print(dir(commits[2]))
# Out:
# ['CHECK_AFTER_INIT_FLAG', '_CompletableGithubObject__complete', '_CompletableGithubObject__completed', '_GithubObject__makeSimpleAttribute', '_GithubObject__makeSimpleListAttribute', '_GithubObject__makeTransformedAttribute', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_author', '_comments_url', '_commit', '_committer', '_completeIfNeeded', '_completeIfNotSet', '_files', '_headers', '_html_url', '_identity', '_initAttributes', '_makeBoolAttribute', '_makeClassAttribute', '_makeDatetimeAttribute', '_makeDictAttribute', '_makeDictOfStringsToClassesAttribute', '_makeIntAttribute', '_makeListOfClassesAttribute', '_makeListOfDictsAttribute', '_makeListOfIntsAttribute', '_makeListOfListOfStringsAttribute', '_makeListOfStringsAttribute', '_makeStringAttribute', '_makeTimestampAttribute', '_parentUrl', '_parents', '_rawData', '_requester', '_sha', '_stats', '_storeAndUseAttributes', '_url', '_useAttributes', 'author', 'comments_url', 'commit', 'committer', 'create_comment', 'create_status', 'etag', 'files', 'get__repr__', 'get_combined_status', 'get_comments', 'get_statuses', 'html_url', 'last_modified', 'parents', 'raw_data', 'raw_headers', 'setCheckAfterInitFlag', 'sha', 'stats', 'update', 'url']

# %%
for row in commits[2].get_statuses():
    print(row)
# Out:
# CommitStatus(state="success", id=7225135587, context="coverage/coveralls")
# CommitStatus(state="success", id=7225129311, context="ci/circleci: build")
# CommitStatus(state="pending", id=7225104844, context="ci/circleci: build")
# CommitStatus(state="pending", id=7225104214, context="ci/circleci: build")
# CommitStatus(state="success", id=7225104191, context="ci/circleci: dependencies")
# CommitStatus(state="pending", id=7225091431, context="ci/circleci: dependencies")
# CommitStatus(state="pending", id=7225089498, context="ci/circleci: dependencies")

# %%
commits[2].get_combined_status().state
# Out:
# 'success'

# %%
commits[2].author.login
# Out:
# 'jcoyne'

# %%
commits[2].sha
# Out:
# 'a525cae6cd8006ddccb08966ecdcc445ab527422'

# %%
commits[2].parents[0].committer
# Out:
# NamedUser(login="web-flow")

# %%
commits[-3].committer
# Out:
# NamedUser(login="kefo")

# %%
closed_issues.keys()
# Out:
# dict_keys(['data'])

# %%
closed_issues['data']['repository']
# Out:
# dict_keys(['repository'])
