# %% [markdown]
# # Sinopia Search

# %%
import requests, datetime
start = datetime.datetime.utcnow()
import json
print(start)
# Out:
# 2019-11-12 15:13:42.088506

# %% [markdown]
# # 2019-11-12 15:08:39.304549

# %%
HEADERS = { "Prefer": "return=representation; include=\"http://www.trellisldp.org/ns/trellis#PreferAudit\"",
            "Accept": "application/ld+json"}
result = requests.get("https://trellis.sinopia.io/repository/stanford/9ba20308-3fe3-4370-81fe-e3b63cb9f71f",
                     headers=HEADERS)

# %%
print(json.dumps(result.json(), indent=2, sort_keys=True))
# Out:
# {
#   "@context": {
#     "acl": "http://www.w3.org/ns/auth/acl#",
#     "as": "https://www.w3.org/ns/activitystreams#",
#     "atTime": {
#       "@id": "http://www.w3.org/ns/prov#atTime",
#       "@type": "http://www.w3.org/2001/XMLSchema#dateTime"
#     },
#     "dc": "http://purl.org/dc/terms/",
#     "dc11": "http://purl.org/dc/elements/1.1/",
#     "geo": "http://www.w3.org/2003/01/geo/wgs84_pos#",
#     "hasResourceTemplate": {
#       "@id": "http://sinopia.io/vocabulary/hasResourceTemplate"
#     },
#     "ldp": "http://www.w3.org/ns/ldp#",
#     "memento": "http://mementoweb.org/ns#",
#     "owl": "http://www.w3.org/2002/07/owl#",
#     "prov": "http://www.w3.org/ns/prov#",
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#     "schema": "http://schema.org/",
#     "skos": "http://www.w3.org/2004/02/skos/core#",
#     "time": "http://www.w3.org/2006/time#",
#     "wasAssociatedWith": {
# ...

# %%
raw_result = """{"took":3,"timed_out":false,"_shards":{"total":5,"successful":5,"skipped":0,"failed":0},"hits":{"total":73,"max_score":1.0,"hits":[{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/hrc","_score":1.0,"_source":{"document":{"@id":"https://trellis.development.sinopia.io/repository/hrc","label":"Sinopia University of Texas, Austin, Harry Ransom Center Group Container","@context":{"label":{"@id":"http://www.w3.org/2000/01/rdf-schema#label"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/washington","_score":1.0,"_source":{"document":{"@id":"https://trellis.development.sinopia.io/repository/washington","label":"Sinopia University of Washington Group Container","contains":"https://trellis.development.sinopia.io/repository/washington/457e2677-935c-4eac-a370-708390589980","@context":{"contains":{"@id":"http://www.w3.org/ns/ldp#contains","@type":"@id"},"label":{"@id":"http://www.w3.org/2000/01/rdf-schema#label"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/stanford","_score":1.0,"_source":{"document":{"@id":"https://trellis.development.sinopia.io/repository/stanford","label":"Sinopia Stanford University Group Container","contains":["https://trellis.development.sinopia.io/repository/stanford/592a0c0b-b247-4d7f-b0f8-447ec1dc816a","https://trellis.development.sinopia.io/repository/stanford/f748647b-659c-4cdc-a916-da32b09976ac","https://trellis.development.sinopia.io/repository/stanford/155fa12a-fa5e-4ec0-b90a-fe8617d4239b","https://trellis.development.sinopia.io/repository/stanford/a54f8854-833f-4b45-87a7-a9c572c6e3f0","https://trellis.development.sinopia.io/repository/stanford/211c8d68-9234-4035-bcb3-c3a10fad68d9","https://trellis.development.sinopia.io/repository/stanford/da2060c7-de29-4bfd-8b4e-7d6a60673c20","https://trellis.development.sinopia.io/repository/stanford/e07513cb-9f98-47f9-9fb8-368a605191bf","https://trellis.development.sinopia.io/repository/stanford/075c7e8e-7bb1-49a5-a391-e84af06ed405","https://trellis.development.sinopia.io/repository/stanford/d8126bc5-301c-46fb-84b5-94d68bb57185","https://trellis.development.sinopia.io/repository/stanford/6b1abefe-3fb4-401f-97ca-f194f7b74717","https://trellis.development.sinopia.io/repository/stanford/421a99c0-4a89-4de4-8c51-fe2cbf08664f","https://trellis.development.sinopia.io/repository/stanford/4c227626-fa3a-446c-9fa8-d502e80627ea","https://trellis.development.sinopia.io/repository/stanford/d45a3a07-d451-44bd-85a7-866ccbf6c5dd","https://trellis.development.sinopia.io/repository/stanford/a38ddcc2-090b-48e7-9e1b-a279c2f14500","https://trellis.development.sinopia.io/repository/stanford/1e5c2019-33a4-4f4e-a3f1-c964eafee390","https://trellis.development.sinopia.io/repository/stanford/5bc2664c-98d3-4176-8fb4-bf3a75cea99c","https://trellis.development.sinopia.io/repository/stanford/1b64915a-a578-407f-8f61-6d2919e6c36d","https://trellis.development.sinopia.io/repository/stanford/c97bbb1c-0927-4713-92c1-2daae9b24434","https://trellis.development.sinopia.io/repository/stanford/451fd5e4-b960-4529-a438-66c456bf49cc","https://trellis.development.sinopia.io/repository/stanford/fd3008fb-7983-4485-944f-81e683e5ccd3","https://trellis.development.sinopia.io/repository/stanford/14c6d613-e700-4b8d-85ba-291ccd9bb1cd","https://trellis.development.sinopia.io/repository/stanford/64e24fda-de39-45cb-b679-65faabd1bd08","https://trellis.development.sinopia.io/repository/stanford/df6315f4-12af-4be1-b91d-379357507759","https://trellis.development.sinopia.io/repository/stanford/2596b2d7-2655-4e69-b414-5fcb31c0305b","https://trellis.development.sinopia.io/repository/stanford/ec9b34b7-6c57-47d8-b8a9-4987a198ada6","https://trellis.development.sinopia.io/repository/stanford/ef23778a-781d-49fa-8320-64fb882098f3","https://trellis.development.sinopia.io/repository/stanford/bf8a28a4-c221-4ff1-9efd-199b3d59ffce","https://trellis.development.sinopia.io/repository/stanford/24bb216f-69a7-4780-ad72-1239727534ef"],"@context":{"contains":{"@id":"http://www.w3.org/ns/ldp#contains","@type":"@id"},"label":{"@id":"http://www.w3.org/2000/01/rdf-schema#label"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/dlc","_score":1.0,"_source":{"document":{"@id":"https://trellis.development.sinopia.io/repository/dlc","label":"Sinopia Library of Congress Group Container","@context":{"label":{"@id":"http://www.w3.org/2000/01/rdf-schema#label"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/penn","_score":1.0,"_source":{"document":{"@id":"https://trellis.development.sinopia.io/repository/penn","label":"Sinopia University of Pennsylvania Group Container","@context":{"label":{"@id":"http://www.w3.org/2000/01/rdf-schema#label"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/washington/457e2677-935c-4eac-a370-708390589980","_score":1.0,"_source":{"document":{"@id":"","@type":"http://www.stanford.edu","mainTitle":{"@language":"en","@value":"the olive and the onion"},"wasGeneratedBy":"I_start_with_K","@context":{"mainTitle":{"@id":"http://id.loc.gov/ontologies/bibframe/mainTitle"},"wasGeneratedBy":{"@id":"http://www.w3.org/ns/prov#wasGeneratedBy"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":["the olive and the onion"],"title-suggest":["the","olive","and","the","onion"],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/stanford/a54f8854-833f-4b45-87a7-a9c572c6e3f0","_score":1.0,"_source":{"document":{"@id":"","@type":"http://www.stanford.edu","legalDate":{"@language":"en","@value":"hi"},"polarity":"http://sws.geonames.org/346269/","wasGeneratedBy":"my:resourcetemplate","@context":{"polarity":{"@id":"http://id.loc.gov/ontologies/bibframe/polarity","@type":"@id"},"legalDate":{"@id":"http://id.loc.gov/ontologies/bibframe/legalDate"},"wasGeneratedBy":{"@id":"http://www.w3.org/ns/prov#wasGeneratedBy"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/stanford/2596b2d7-2655-4e69-b414-5fcb31c0305b","_score":1.0,"_source":{"document":{"@id":"","@type":"http://www.loc.gov/mads/rdf/v1#adminMetadata","descriptionStandard":"http://id.loc.gov/vocabulary/descriptionConventions/rda","languageOfCataloging":"http://id.loc.gov/vocabulary/languages/eng","recordContentSource":"http://id.loc.gov/vocabulary/organizations/dlc","recordCreationDate":{"@language":"en","@value":"10/1/2018"},"recordOrigin":{"@language":"en","@value":"stanford"},"wasGeneratedBy":"sinopia:resourceTemplate:bf2:Agents:AdminMetadata","@context":{"wasGeneratedBy":{"@id":"http://www.w3.org/ns/prov#wasGeneratedBy"},"recordOrigin":{"@id":"http://www.loc.gov/standards/mods/v3/mods-3-6#recordOrigin"},"recordCreationDate":{"@id":"http://www.loc.gov/standards/mods/v3/mods-3-6#recordCreationDate"},"recordContentSource":{"@id":"http://www.loc.gov/standards/mods/v3/mods-3-6#recordContentSource","@type":"@id"},"languageOfCataloging":{"@id":"http://www.loc.gov/standards/mods/v3/mods-3-6#languageOfCataloging","@type":"@id"},"descriptionStandard":{"@id":"http://www.loc.gov/standards/mods/v3/mods-3-6#descriptionStandard","@type":"@id"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/stanford/fd3008fb-7983-4485-944f-81e683e5ccd3","_score":1.0,"_source":{"document":{"@id":"","@type":"http://id.loc.gov/ontologies/bibframe/AbbreviatedTitle","mainTitle":{"@language":"en","@value":"This is a new book"},"wasGeneratedBy":"sinopia:resourceTemplate:bf2:Title:AbbrTitle","@context":{"wasGeneratedBy":{"@id":"http://www.w3.org/ns/prov#wasGeneratedBy"},"mainTitle":{"@id":"http://id.loc.gov/ontologies/bibframe/mainTitle"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":["This is a new book"],"title-suggest":["this","is","a","new","book"],"subtitle":[]}},{"_index":"sinopia_resources","_type":"sinopia","_id":"repository/stanford/bf8a28a4-c221-4ff1-9efd-199b3d59ffce","_score":1.0,"_source":{"document":{"@id":"https://trellis.development.sinopia.io/repository/stanford/ec9b34b7-6c57-47d8-b8a9-4987a198ada6","@type":"schema:Thing","name":"Casie","@context":{"name":{"@id":"http://schema.org/name"},"schema":"http://schema.org/","owl":"http://www.w3.org/2002/07/owl#","xsd":"http://www.w3.org/2001/XMLSchema#","skos":"http://www.w3.org/2004/02/skos/core#","memento":"http://mementoweb.org/ns#","rdfs":"http://www.w3.org/2000/01/rdf-schema#","acl":"http://www.w3.org/ns/auth/acl#","geo":"http://www.w3.org/2003/01/geo/wgs84_pos#","dc11":"http://purl.org/dc/elements/1.1/","as":"https://www.w3.org/ns/activitystreams#","rdf":"http://www.w3.org/1999/02/22-rdf-syntax-ns#","ldp":"http://www.w3.org/ns/ldp#","time":"http://www.w3.org/2006/time#","prov":"http://www.w3.org/ns/prov#","dc":"http://purl.org/dc/terms/"}},"title":[],"subtitle":[]}}]}}"""

# %%
import json
result = json.loads(raw_result)

# %%
result
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 73,
#   'max_score': 1.0,
#   'hits': [{'_index': 'sinopia_resources',
#     '_type': 'sinopia',
#     '_id': 'repository/hrc',
#     '_score': 1.0,
#     '_source': {'document': {'@id': 'https://trellis.development.sinopia.io/repository/hrc',
#       'label': 'Sinopia University of Texas, Austin, Harry Ransom Center Group Container',
#       '@context': {'label': {'@id': 'http://www.w3.org/2000/01/rdf-schema#label'},
#        'schema': 'http://schema.org/',
#        'owl': 'http://www.w3.org/2002/07/owl#',
#        'xsd': 'http://www.w3.org/2001/XMLSchema#',
#        'skos': 'http://www.w3.org/2004/02/skos/core#',
#        'memento': 'http://mementoweb.org/ns#',
#        'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#        'acl': 'http://www.w3.org/ns/auth/acl#',
#        'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
# ...
