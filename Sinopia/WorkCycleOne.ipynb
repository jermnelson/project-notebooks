# %% [markdown]
# # Sinopia Work-Cycle One
# ## August 2018 to July 2019

# %%
import datetime
import json
import os
import requests
import sys
import pprint
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath('.').split('/Sinopia')[0])
import src.sinopia.github as github
import src.sinopia.data as data

# %% [markdown]
# ## General Repositories Stats for LD4P Sinopia Project

# %%
commits = github.commits_query()

# %%
pprint.pprint(commits['data']['repository']['ref']['target']['history']['edges'][0])

# %%
pull_requests = github.all_pull_requests()

# %%
for i,row in enumerate(pull_requests):
    pr_filename = f"../data/json/pr-{i:04}.json"
    with open(pr_filename, "w+") as fo:
          json.dump(row, fo, indent=2, sort_keys=True)
# Out:
# 0 100
# 1 100
# 2 100
# 3 100
# 4 100
# 5 86

# %%
def commits_per_pr(pr):
    node = pr['node']
    commits = []
    print(f"{node['number']} {node['title']}")
    metrics = { "additions": 0, "deletions": 0, "commits": 0}
    for commit in node['commits']['edges']:
        metrics["commits"] += 1
        commits.append(commit)
        print(f"\t{commit['node']['commit']['oid']} {commit['node']['commit']['messageHeadline']}")
        metrics["additions"] += commit['node']['commit']["additions"]
        metrics["deletions"] += commit['node']['commit']["deletions"]
    return metrics, commits

# %%
work_cycle_one_commits = { 'metrics': { 'additions': 0,
                                        'commits': 0,
                                        'deletions': 0 },
                           'commits': []
                         }
for row in pull_requests:
    pr = row['data']['repository']['pullRequests']
    print(pr['pageInfo'])
    for node in pr['edges']:
        metrics, commits = commits_per_pr(node)
        work_cycle_one_commits['metrics']['additions'] += metrics['additions']
        work_cycle_one_commits['metrics']['commits'] += metrics['commits']
        work_cycle_one_commits['metrics']['deletions'] += metrics['deletions']
        work_cycle_one_commits['commits'].extend(commits)
# Out:
# {'startCursor': 'Y3Vyc29yOnYyOpHODQVehg==', 'hasNextPage': True, 'endCursor': 'Y3Vyc29yOnYyOpHODkj0Jw=='}
# 11 Gruntfile: reformatted whitespace so tasks line up
# 	2125557aa8e65044a9f7fa28349cc4ea1c0a74ca Gruntfile: reformatted whitespace so tasks line up
# 12 add eslint task and packages
# 	3febb8d71f54417c435531dc81e58bb7b312c2f4 .eslintrc.js:  initial config
# 	10024582c81d608e32cdeb51fec0d98ad679c62b add eslint task to grunt (and package changes needed)
# 15 add jest along w npm and grunt way to run it
# 	124cda43a99c4042c16efe8d5742eaa918c4584b npm test script runs jest tests; jest devDependency in package.json
# 	c4bc81f5092dffb47542f0b365a08b2bfdea8067 add grunt-run package
# 	bf6d90a5cb2d18f4a79ca2a7398acd0af401bb1f Gruntfile: test task runs jest tests
# 	5dd687f0fb666c339e5e07ba9a3acdd10086e9b4 add grunt test-cov task to run test coverage
# 	b5440e8aa72e826f48592a973a87a9d94c031f0a .gitignore: add coverage and .DS_Store
# 20 circleci hook up
# 	14a8c58a2c14f88b2abb6333e640aa1a4133c4ba package.json: npm task name now jest-cov, Gruntfile: shorten internal…
# 	ab3f6e1a455c4800eb6fe6a131fecd346ec66e87 .circleci/config.yml added
# 	b1c838dd5cb6aa8f1440f9438a4fc1b828f0ea31 README: add circleci badge
# 	1a8ec242cf52da00e7fdf26c82d98c72aeec38bf add npm jest-ci script which uses jest-junit reporter
# 	e0e6da727e872714ab668fdee311a66fd90b8fcd circleci hook up test summary view
# 	7aaac7c510c22950390682e3675c5c6e90410372 make test do nothing to get circleci to pass
# 22 package.json: fix descriptive metadata
# 	16cdd8c998f21f719db3d05beefd59868d2219b1 package.json: fix descriptive metadata
# 23 npm grunt-contrib packages are dev dependencies
# 	59cb77070a65af15fed4912eccc8d237c43f5dca npm: use released grunt-contrib-uglify-es and make it dev dependency
# 	3848e634a2738caf67dea0fd9fdea93c9d425b95 npm: grunt-contrib-cssmin is dev dependency
# 	40dcdedce0f6501925ec8728b7582f5125fc3a1a npm: grunt-contrib-concat is dev dependency
# 24 package.json: lock to node version 10.11.x
# 	9b8c7f9391f953c3860ea88030c95d5f46a12aca package.json: lock to node version 10.11.x
# 31 minimal integration test passes and some additional build refactors
# 	12810978cc4d265cd73d571db24fa8b50905578a grunt tasks clean builds dir first, and runs build before tests
# 	48b7b9d907cf457cd1b67d175bdd2c4311f8199a grunt: cssmin add_banner task removed (never did anything)
# 	7f3adc20c1787796403e874f30c126ffdd7b249b grunt copies static js files to builds directory, as it should
# 	ad0d563409cfb51ac416a63af972ea9e8fb1bc62 .circleci: remove comment about switching to using grunt in CI builds
# 	94600a94914f57bd2f4c1864cfdf4b5cfd26f75b jest-ci: run grunt (build) before running tests
# 	a1f26eb595f04d7a8360fb858098bac267776ec3 static/js/lodash.min.js removed as it is loaded vis http in index.html
# 	e88d9e6175d76e0d7f0928e889b03d664330d123 Gruntfile: only copy js mentioned in index.html
# 	bf81b209eeb025866fe3ad06682d603e89807b82 npm modules jest-puppeteer and puppeteer added
# 	3944d029f7f6e86a9aa6b7fce3dfd0f7cb13d2ac initial basic integration test added
# 	f654a57aafa8de67efae58b7a31984eb46e26c44 remove noop test
# 	79884668e082f6e4890e19da17cc8be016837589 index.html: update to use js from builds folder
# 	99f75ec72443ca749e9799df8c8e089898210181 Gruntfile: put css from build into css subfolder
# 	dda84086aa5db9619fa0c65df8619a51725cc4c4 package.json: use jest from freshly built node_modules
# 	6c6f908ff032b9eeb20b56b856ae7e744c0c0033 circleci workaround for puppeteer
# 33 circleci runs grunt as step; removed from jest-ci npm script
# 	69875d5763086ce8a4feb88ec8df8305104e1be1 circleci runs grunt as step; removed from jest-ci npm script
# 35 CI build includes eslint, which will fail on errors or additional warnings
# 	14549871d6d15b958e28165c0ed50cf908e73725 package.json: add eslint script
# 	6e4e82154ba852ee38d95afe841809ea0d4872a1 express npm package is a dependency, not a devDependency - sheesh
# 	88a54019dba9d6e7d9ec04819181efd83bda9766 aceconfig.js: fix lint error
# 	ed6f8a92ed0140f8cff88c0a6e14381132f1e64b bfelookups eslint fix: avoid redeclaring li var
# 	25495e8682a72313d266bb69c8dd9182edf03b03 eslint hooked up to CI and fails if warnings increase (beyond 1319!!!)
# 	8d37d6296f7cbc0db868b6d63774bf0aaec24449 bfelookups eslint fix: don't self-assign
# 41 add static analysis with es6-plato to circleci build
# 	e7ec91e4624d163b3d32734c72826b10a5122d33 add static analysis with es6-plato to circleci build
# 42 circleci uses appropriate docker image
# 	f60f79e8cc39f4c25babe8b19ef6ba9eb0fd36ea circleci uses appropriate docker image
# 43 .eslintignore: add static-analysis directory
# 	1b993e1fbaa57fd90faa6ec0d5e57cb065b004c7 .eslintignore: add static-analysis directory
# 60 eslint-takeoff added with generated eslint todo list
# 	eb097c64a834999280e2c6cf5a9e62540947c0e4 eslint-takeoff added with generated eslint todo list
# 61 use scss-lint for CSS
# 	2aa2a394e1329a7031dff327c82c08293b24a7c8 can run grunt scss lint
# 	9ccfa90bb0989a454ef5132d680c7c6dca93d9e4 .scss-lint.yml: rules turned off according to --format=Config
# 63 Renamed basic.test.js to landingPage.test.js
# 	55c1434f5444406a7fe6df9a8070c7364c295135 Renamed basic.test.js to landingPage.test.js, the Sinopia Home page will
# 64 README updated for LD4P sinopia_editor
# 	03fe13890c9e6d2f2dad559e61eda1fa681060c3 README updated for LD4P sinopia_editor
# 65 add profile fixtures to __tests__/__fixtures__
# 	601c9e064689968dd3ed097a69f043fcc940ca98 add profile fixtures to __tests__/__fixtures__
# 67 Tests for Profiles datatable,
# 	e9577a8a4bcd3e88a8b34c3737edd7240a01d9c7 Tests for Profile datatable, checks for Search, table columns, and pa…
# 	121b745ed1068f12dec58965bc09e6be8af53f84 Addes global page variable to eslint config
# 68 tweak browse test descriptions
# 	b69a4b825da2909254445228de30599b8d0929c3 tweak browse test descriptions
# 69 integration test can affirm that profile is loaded
# 	35c99701ea76f78425c8b2737492322f674584fb add fixtures for shortened verso profiles response, instance ontology
# 	70c1d630ed8a7d9319a639c29343e287eef9bff2 create test versions of index.html and config.js
# 	d36ac1bd94ebb559e6f8de5da7489de956c7c7ce jest-puppeteer.config turns off CORS
# 	13ac4f90e5efc58a8d7e31b2a6794a9428f4c0fe test showing monograph instance profile loads
# 	471260189ddbd7318e799407be9e5aeee44110cf greatly reduce eslint warnings by adding more globals
# 	eab6f960cbfee603cbd3aadd1d1616710f989181 package.json: test-config.js does not contain jest tests
# 72 WIP - tests no longer need test-config as LC verso is now open to CORS
# 	3bfb6b962d23ed0a717118b3aa3b857d1bd42257 tests no longer need special config as LC verso is now open to CORS
# 	ee52c23f6cc87bc85bb466d963d02b815f045bae down to 760 eslint warnings without test-config.js
# 	cc4469f11ec8e3aa657968c92edfd2d749428552 jest-puppeteer-config: re-disable web security
# 	d2c4603d16a24681e3f99c514c0d695089484d14 jest-puppeteer-config: re-disable web security
# 	79fa533211573b629a054cf893b04666e194bf89 loadedProfiles test: turn on console logging
# 73 Editor tab testing of default profile menu and submenus
# 	66c6094827a157a58c6dc8aff62f31145574ce23 Editor tab testing of default profile menu and submenus
# 74 tests use expect_regex_in_selector_textContent function
# 	3febcbfa12a593aaf384ba55d1121642df1298c4 tests use expect_value_in_selector_textContent function
# 81 tests for more functionality of editor tab with loaded profile
# 	d4e839ca5a73bd03c14af9273298e485be4c27d9 bfe.js: add specific context to error message loading resourceTemplate
# 	ab4571bfe69320a6fdf27ba0bee052154fc4dc3c test index.html:  use builds/bfe.js instead of builds.bfe.min.js
# 	07f22ae5a66399a8602fd90689da87e86f515de0 jest-puppeteer.config.js: comment why disable-web-security
# 	6bc2bf079001638b302efb77ff7e23b86bbcbd88 profilesLoad test: work for ticket #53 and TODO with tickets for rema…
# 	9bc69e30595964b283b6a6ebbb62611bed5a6cd8 profilesLoad test: use templates literal instead of string concat
# 83 Build and post a Docker Container from Circle-CI
# 	bc764a992d46e5a58ab6b379243c618e7ba16586 Use YAML aliased defaults
# 	0212589b8852aea5ca88ce8e3437941a23a7aa8e Build and post a Docker container
# 	c692e8050be3dc3f77228c34b7929b78405a4037 `npm install` reformats `package.json` w/o semantic difference
# 	0a692becfc2c1e1737ea443c29ddfbf4b266a4e1 Only build "latest" container from master branch
# 85 Setup react
# 	477c435c7fd9ac47e6242ee995ffbcd978c25ec7 Added React, Webpack, Babel, for basic react setup
# 	646225193d370397043861de6010837b64b9a17d Allow index.html to be used from home directory and not dist/
# 	4512ddd523ea9bdfa6fef6a49c81f797121803be Add style-loader to view .png, add basic header Sinopia image
# 	0dea791b2ddc972b04ea80e1115fd4573330d27e Added React, Import and JSX-a11y plugins. Set up the parserOptions, S…
# 	f82150d08af4f64dc4c5223b1118a5f146ed86c6 Add babel-core7.0.0 and stub out tests for now
# 86 Remove serve-static from direct dependencies
# 	67cdae3f324099645b6f8501ec99ae849694f95f Remove serve-static from direct dependencies
# 87 Setup news panel
# 	8eb7354d33c513bb90800f5e1e9926de4576ac33 npm dev-start to use webpack, set up node server to use dist/, add Jq…
# 	0a18558c4fb33498863356ba0985c2d106044b8a Add CSS loader and Style Loader. Style the Header and Add a LoginPane…
# 89 React test setup
# 	603daf0797092c3cce5efa2752af71ef341ab01e Set up the correct dependencies for jest testing w/ enzyme
# 	06159c4779c0173626c0448ab014581e40e026f9 Setup Enzyme, mock out importing of PNGs, introduce dependency for cs…
# 	113ba663c16aa836a53582470b5ecd9614817ddd In react use className not class
# 95 Updating merge version
# 	20f6bb8ed9e847982965d5accc33b6afb1474769 Updating merge version to fix security alert from Github
# 97 server.js, bfe-index.html and other housekeeping
# 	d342bcfc849a790722c1c088431ad565e41f0196 rename server-bfe.js to server.js
# 	68eda6b0967076a5d8d0dc2c19acacadc4cb78a1 bfe-index.html added for easy way to work with bfe functionality for now
# 	3823cbf82b1f1c25c358922c8c9114008c433030 package.json: add install-build script and add documentation to README
# 	5c2d4e13919ec32543026a4de96590746efe4c68 README: remove some cruft
# 	bdcb384b4b65fe31feaf50b3234e6694e85a06b1 README: added info re: webpack build vs grunt build
# 98 Add DescriptionPanel and Some Styling
# 	0f6bbfe7336f1b2c373dcac9588525d57a83a146 Decrease the size of the jumbotron font
# 	117677c7546b6f553a88eceec02e4042a0db4a78 Add Description Panel under News Panel
# 	edd64f7583262a4e62dd486646676ee8288e9786 Add build script to create dist/ folder
# 	ec34ed0728207cdd2efac1fd766452427daf975a Use node server-bfe.js as command for docker
# 	c42b10f62424b2edf4099388e080157104b8a9b2 User Source Sans Pro as font style
# 99 Add Footer with more Styling, and adding items to drop down menu
# 	ec800542945643c0baad5b9ac9088d8810673d3d Add Footer to Application
# 	c6e78ca20a7bee09b32697e04ee67d62cce7ef62 Add more menu drop down options and some styling
# 	345e49716608184630ff5b8449870992a969c317 More misc styling, menu items have blue color, add box shadow for panel
# 100 Finish up HomePage Tests
# 	e520456a3d24f1ade6f8a3c1c2fd7d2dd01d4c0f Update dropdown menu jest tests
# 	efb151b34271d30d870bf844ce2381db045108bf Add Description Panel Test
# 	e9b47722b4d0ee6cd24be4fdf577f63c0bd37171 changed for element to htmlFor in LoginPanel
# 	af9cfb288a8dd016ca021e77c50376b3b1a1df05 Created NewsItem component
# 	0e5e53d9f61a2e98aa3d0e4f37ebab3abb2005f0 Add LoginPanel tests
# 	0ea55b6db83827da58a079ba069bcad1a6a6446f Add NewsPanel tests
# 	8bb6fcad9fb111ef4f77c87a6cea47b5b0d460d7 Add Footer tests and update LD4P link
# 101 can now use npm start
# 	74dd001194784d0a9dad6861945c9fa3761ed3e2 can now use server.js
# 102 remove config-dev.js and development.html
# 	3c97a257c9871438ffb3e5efe57a32a55f344245 remove config-dev.js and development.html
# 	7df0c41918574f028f01376f1be8f2f8c2b2ba02 .eslintrc_todo.yml regenned
# 103 use .dockerignore file to exclude unwanted files
# 	08bdfa945719943f108cd70850eccca09dd15201 use .dockerignore file to exclude unwanted files
# 104 Remove windows line-endings in source via `dos2unix`
# 	f247ef55327b199b5d0591659cf9bd757b22e848 Remove windows line-endings in source via `dos2unix`
# 107 Update Latest News on Home Page
# 	aae0880bb10fd900ed4e0131bc074c5948079dd2 Update Latest News on Home Page
# 108 Updating README with the latests command to run the Sinopia Editor.
# 	d1756d477785896c89fc20dddfd2799f400a7322 Updating README with the latests command to run the Sinopia Editor.
# 	72226a31c18fbf1a53f4a6aac320913825b13452 Removed build step from running with webpack
# 	4a0970a2a5253d9e90f14237c13c7c935c27b55e Copyedit that clarifies some language, removes hard-breaks in text.
# 109 Include "dist" for container, not "builds"
# 	fdc6a16aaeefd805a8f03a0b01af83ab1a933423 Exclude grunt "builds" from container.
# 	cc709139e5541edd9bdbceac2e0383f6a1bdbf1c persist "dist" between build and register_image tasks
# 110 versoSpoof for profiles and cachedHttp for ontologies
# 	641201ae3c2708b7d940b5faf1b8aaff8331af1a sample_data_from_verso added for spoofing
# 	c9407ef3fe2321748d451d067756b6b728ceb012 owl ontologies added to static/rdfxml
# 	2cbd14d9fc72d95984f91460ee617dd97c3c6c20 added x2js npm package
# 	e582ce1f384ab6c4d848cb61db2c2eecbc9ff092 add versoSpoofing for profiles and rdf xml ontologies
# 	60f638728706ed5089b78083e15f3d8dd46ee572 versoSpoof: add id.loc.gov Instance and Work ontologies
# 	039e981c48ee72695a64fa8ab29f4abb728b190f versoSpoof: profiles now at static/spoofedFilesFromServer/from_verso ...
# 	9cf868a094a8e06a70c9192a8915bdfd92a5e39a versoSpoof: cached rdf xml ontologies in static/cachedHttp
# 	64d3ea954200cec624b36735a212aa8ff3b4ad6c versoSpoof: cached id.loc.gov ontologies now at static/cachedHttp/id.…
# 	b744ce8e014d72a194bb2ec74ca7ad3baacbdb2e config.js: rectoBase set to localhost
# 	5bb9fa1caa91aef9081909fb92208c71cab9a7a9 Merge branch 'master' into versoSpoof
# 117 Implement React router to link to editor page
# 	e78123e8791bfc03a7580c495d6d9490f8b36458 Create separate react componenet for total homepage
# 	a1ee6d05164c2b0343a0f695f39d5637b5a77ddd Implement react router, link from homepage
# 	b8f5268a08d28b55ce36f07322cd4c46d6e2e8f6 Update react-router tests for App.test.js
# 	906cd57f41e5742800922c12db62c61219bb0785 Required to use mount() for enzyme
# 	dbd0a0a3750b80888ff36ac7b26d2fbb693edc3d Remove semicolons from all __tests__ and src/ components
# 118 server.js: better error messages when spoofing falls through
# 	36ab1e5eb15cc8eea3c7a99106fd95fb60c95594 server.js: better error messages when spoofing falls through
# 119 update Editor route
# 	86010c033c40b13f4e507db6a8664c40218e3a60 update Editor route
# 120 Homepage slide out menu
# 	eba5081361db2acf640e7e92f500968898a3279b Install fontawesome for symbols, and react offcanvas library
# 	93173545b5e41286c08d51e10fdfc625aa881ed7 Add offset canvas to homepage w/ tests
# 	6490cf2ea8debf3081ab4bd8899ce2279154c3e6 Add CanvasMenu component
# 	efd559d529792e72ff354332346f80562d7f8917 Header now uses CanvasMenu
# 	2115fda4c0a663de73e8f284685cf186c9120fa7 Update CSS for Menu styling, Add Footer to BFF. Remove Footer from App.
# 121 Changes link to Sinopia Profile Editor
# 	fef393fa1c02368cc385fec62490cb1253764e29 Fixes link to Sinopia Profile Editor
# 133 Editor beginnings - render static text for hardcoded resource template JSON
# 	7aa058d75a19c720cba364a227a28e27d34dd451 Editor components: initial parsing of hardcoded resource template - s…
# 	1f1c35594fe1265e9b696612236405ad9e3749e4 DescPanel.test: change test description
# 	9c72571cc349b26ef3483cb59b09cb9c5b20c319 HomePage.test: fix description of id test
# 	ed49f82ed60f98a3cbfa3107321c0842cd1021e6 App.test: use Editor component, tweak tests to be more readable
# 	73eef685a48dcc32ca17a7b3f7c2282420025ffd App routing tests fixed
# 140 update footer image and description
# 	4a9b9e8745c1f135eb1d6902ced5048119cf5af1 update footer image and description
# 143 Rebase internal header
# 	fd73118dd24a8642dc44b814e9d8e6ad4f92abc1 Add Editor Page images
# 	647a47f0218c48ccc45e79566d01fb3f46a8edb1 Add new internal editor header
# 	0ac4899374f1c61ad518f842c782487fdedc8791 Add OffCanvasMenu to APP, so Homepage and BFF can access sliding menu…
# 	17bb2be150af887e9f2275d98873dd6ff446283b Fix tests, add Footer test to App.test.jsx
# 	c248b69f182a64e8ba712fb40be277c6b7ffe46d Update Editor page w/ header
# 146 Apache 2.0 Header added to Source Files
# 	54400c7e013221744ea5b92d7412b08bba88b338 Added Apache 2.0 header to all source code contributed by Stanford De…
# 	94bc56d3a2ee813b2777c3fd60489b72e2d878b9 Removed LICENSE.txt, added new LICENSE with Apache 2 and Public Domai…
# 	f08449fd39c68c6c2b260ef4d95ab7d776542522 Replaces Apache header with single line reference to Apache2.txt
# 148 Adds components to render resource template value constraint properties
# 	0931693248e3d18fbfeee6b9ec686693f928d4f5 Adds components to render resource template value constraint properties
# 	3ed9f94e3b4351d70ff4f9554b62c04ada93f3e8 Adds a fake propertyTemplate that has all of the valueConstraints fil…
# 150 Adds a placeholder starting points menu
# 	b9e2803d0459ad19057c6529a0f3ece6ff139c02 Adds a placeholder starting points menu
# 	34c87fea86d9f0ed65b6da2027ae27c7518c3581 Merge branch 'master' into starting-points
# 154 Fixed 404 when GET editor directly or refreshing page
# 	5f6c30ad2b732f54f913f51347697539951ad1ad Fixed 404 when get called on editor directly or refreshed
# 155 Minor improvements I stumbled into while working on sinopia server spoofing
# 	151fe1fe14b7448add5aa4cf5dff9cdf65a216b8 package.json: add dev-build, dev-build-test script to build faster (w…
# 	aecf2ffa9b6a95138c86e81ff13fcbff3eef67ce README: updates re webpack vs express server and dev-build script
# 	caea8dc12ef99ac7fda39c365aa7da237afc1290 editor components: avoid attempts to render undefined objects
# 156 Adds tests for rendering of PropertiesWrapper component
# 	aef979d7bec39d30c19fe0307c0c90e4c1389a61 Adds tests for rendering of PropertiesWrapper component
# 157 Moves EditorHeader component to component 'editor' folder
# 	66bb4fe98970633b7d4cadf342cc4df7c95c029e move EditorHeader component to editor/Header
# 	ac8538bfc47b2e4473154abc06c9fe335429beea editor/Header: remove unused imports
# 162 Add more description on creating new docker build
# 	2277e2b196551105f593dda666e035a44d1133b4 Add more description on creating new docker build
# 164 remove grunt from our application
# 	b427856e7712c2bce19c66615d2f7c84a28afa3f remove grunt from our application
# 	ba2de399dd930e4745537dcdf88a79412e4e497e Update circle-ci build
# 	7b954f88ab48aafb7cde40065a86b39a02976e3d Update README and remove references to grunt
# 167 Spoof resource templates from server
# 	c94be7e910abf02ee0bb0fe878ea066743a173d1 sinopiaServerSpoof added with static json files and tests
# 	d643c22f932c07696179df77409120cbabb5585f Editor component uses sinopiaServerSpoof
# 	66e403b3dc119028f0d092da884b6193dfebcf67 Editor: remove commented out debug statement
# 169 Unmounts renderRoutes component in App.test.js
# 	559e404deabe17ab342038cff66bb9fb50cfe748 Calls unmount on rendered component in test
# 170 BFF: Fix code coverage
# 	0023c4bb052db7dbc9d279c8be6757d7dd848ae4 code coverage: include jsx and don't include bfe
# 	4010221ab7bf0a4bff6e376d1e1ab3a151cdf9a5 package-lock.json updated with 'resolved' urls
# 171 update npm dependencies
# 	aa868b9bd24000fcb6579485970502c51e78786f update npm dependencies
# 176 make eslint more useful
# 	b9265a5d90325c3c6d1e5653991e87cb5228e9f3 add BFE code to eslintignore
# 	60f5c3a8b9b8ea8296507ee70a760e488c38e547 ResourceTemplate.test: get rid of commented out PropertiesWrapper cru…
# 	952eb79db018cb75874dd3d7b35edfecdbf348e2 eslint: add jsx files (only can do via script in package.json)
# 	5c3148631d8d1fc8dcd2158da9caf2094be43401 eslint: avoid complaint about unknown react version
# 	5d4040ebf93520d1764007e6fcbfe71131930729 eslint: remove unused exceptions to rules
# 	e37a194c55b88c7c51fe9638b6a9ea24ec7c19e8 eslint: add security recommended rules
# 	45168e882623d511c93cc01911506a187d329909 eslint: use ecmaVersion 2019
# 	e703e118a500bf34b761c4713ed161522bced38b eslint: use babel-eslint parser, since we use babel-loader for react
# 	1f67fba3a29f4ab04922d3047175fdb8c4255f0e eslint: tweak rules and file organization to help us work with OUR code
# 	d0844fa29de480e91e192995280578fda7eb133b package.json: eslint gives 86 warnings before correction - dialed the…
# 	e12015065d1c1c41b3383ca4b70f8f59e9d974e6 Header: add missing alt text to Sinopia logo img tag
# 	c880229968e253d66cfa4ea41e5303a21f1d6f53 ResourceTemplate: remove redundant 'role=form' from <form> tag
# 	d5828eb62698dda4f7934e40c58d70180e950512 eslint: turn off semicolon rule - it's not important
# 	e1b8977e4eda70f461aaa342b9dbdeb24a4dbe04 eslintrc: better explanation of bespoke rules configs
# 	7934e52fd426fdf5e248a8cb0156d8a7766505fb avoid unescaped html entities
# 179 Use FormWrapper instead of PropertiesWrapper
# 	515e8dc6a667c92c74fe3511a983ec028b9312f4 Use FormWrapper instead of PropertiesWrapper
# 	0457af979c48fdce5bcb7e58025ba9f8576a73f8 rebase - update eslin
# 180 create input text field for propertyTemplate (Type literal)
# 	8008991171b2fb50432150d43faca90eac74e733 Add inputliteral component w/ tests
# 	dcfc2af30a7d1e388aa881d1b3b64595bf0f791f add resource, lookup, and target stubs that we will eventually remove
# 181 Updated anchors with target="_blank" to include security fix
# 	02fd67a759c3db2da08f095ae67c965f13c00827 Adds rel="noopener noreferrer" to all target="_blank" anchor tags to fix
# 	c10ae644babb57d42d641bec0a33ba0b31f3f47f Removed target="_blank" rule:
# 183 Update Description Panel with new text
# 	b8687a00d547f0f9eac9ddfabfc942a6d44ac33a Update Description Panel with new text
# 	21a91e4be0cfbd0c0d8b9b3aa101711859e9ed10 Sarav - added some tweaks to styling
# 184 SinopiaServerSpoof: exports getResourceTemplate so it can be used anywhere
# 	2a2ec675f695117a1cec240b74a6c0cbdf3fbc2e SinopiaServerSpoof: exports getResourceTemplate so it can be used any…
# 	09dfe2254e84a52b189fe6ff1b075c3d16d4b158 ResourceTemplate is given an id; it fetches the ResourceTemplate with…
# 	c0f7249f074fe109f9467b197055099a1d3397d0 ResourceTemplateTest: remove 2 blank lines.  whee.
# 	31dfa0fa61cb42341b46038045f495970256e583 FormWrapper: fix complaint about missing unique key for array
# 	a0bd9e726ee83f50631dc59dce68d02c6c6abdd7 eslint: warnings down to 60
# 185 circleci: don't do static code analysis and don't store coverage or analysis artifacts
# 	fe78b4591eef4fd41cba3282fef6af94ae1fb146 circleci: don't do static code analysis and don't store coverage and …
# 190 add ci script to package.json so we can run it all locally in one step
# 	a47ed484cadcdec18e52fc8d1fa18762003aa2cc add ci script to package.json so we can run it all locally in one step
# 191 FIX Warning: validateDOMNesting(...): (UL cannot be child of <p> tag)
# 	455728e5344e9aca058747c8180c70032bc2b9e7 FIX Warning: validateDOMNesting(...): <ul> cannot appear as a descend…
# 193 Adds propTypes and tests to React components
# 	834612ef4e83b928c936c84808cf8b81fe0d0011 Adding propTypes for Components props. Expanded and adding tests for …
# 194 Add the copyright notice at the top of Stanford's files
# 	c1667d68bebf6ce436a7ad78ae6527a325abee9b Add the copyright notice at the top of Stanford's files
# 199 Adds form select options from spoofed target list
# 	19b890ec31fb014ca94764de9cc07dfca7a5cadd Adds an input with select options from a target list using react-boot…
# 	03d91c311384587b2cdecab43f9bc3998f2c5c78 We do not need tests for propTypes
# 	8175100953474503f2b987e9bca3d7fd11b1ae92 Merge branch 'master' into input-target
# 202 Updating from Library of Congress Verso Profiles
# 	0c942765bc597b91a48951a0dc33d19ead82aa8a Updated Verso Profiles from Master Branch including README.md
# 	05905710652a2d8196c114ae8ba17566c89e4ca7 README deletion and removed log from test
# 205 Downgrades event-stream to 3.3.4
# 	782e95c0a7d9df1cf958a968f4c7b34cfd313b2b Downgrades event-stream to 3.3.4 and removes flatmap-stream as a
# 207 Repeatable mandatory input for type Literal
# 	f5a6899acd617f6efda7bb412dc9ba959a3906e5 Implement Repeatable input that is non/mandatory
# 	ccfe00e3283b8095c9cee8af54db02bee4b2c5b1 Add enzyme tests for propertyTemplate attrs
# 	683c7ef76edb7fee35655068d5bdb8dc5c8bf808 Add PropTypes
# 209 Adds Input lookup component
# 	e3066462f9377379bc5fb474143f812110576a70 Adds component to do typeahead lookup to QA service using react-boots…
# 	a0b1b49b7b781a8585fa8d55bd5e9781960888fb Adds test for onchange event
# 	c5095129c752f251f4cc18454f6903ea36dcbcab Add tests to simulate  onChange and state change, increase code coverage
# 214 Editor uses hardcoded rtid of resourceTemplate:bf2:Monograph:Instance
# 	32d1d894d2049a2966d674653158f5e890fa8929 Editor: keep hardcoded rtid as monograph instance; added target with …
# 	e7d982df862b1170eaded3471fb4c94b0426c597 spoofed MonographInstance: changed remark to indicate it has been mes…
# 215 Follow on work from Repeatable and Mandatory Literal Type
# 	7744dd6cedbcea62a7ec43b68a90d293fec9b22c Follow on work from Repeatable and Mandatory Literal Type
# 216 Add modals for properties with valueTemplateRefs
# 	837529d12d4449780ae709ac12898eb9427c2917 add @babel/plugin-proposal-class-properties to allow arrow functions
# 	1cc7949048e077976dd37d0bb670746adc8a51d2 ResourceTemplateModal component added
# 	15a5210b1c9a621b1faa2d083c4a99eeae697d8d ModalToggle component added
# 	d987c055a9e21616956b3d0e3ab9a037f9843f95 ResourceTemplateForm component added
# 	3a19579969d75e471f693b1a6703d8f0b727c192 ResourceTemplate: use ResourceTemplateForm instead of FormWrapper; br…
# 	f23d579444e74d024dab186800dc41b9ee76b3aa remove FormWrapper (replaced by ResourceTemplateForm)
# 	9282889ab2a028c1966cc9333e4f8011041d9acb removed unused PropertyTemplate component
# 	66ff96a16eb49f78197799188424e4e3f6742df8 removed unused ValueConstraints component
# 	0b82e0751aac304cf6be341002b32511cf64cf8b add spoofed Barcode resource template to avoid error messages when ru…
# 	ccce303fc680f516cd63fb42b7e6bf07072ff94c ResourceTemplateForm.test:  remove confusing comment
# 227 [WIP]Adds form select options from spoofed target list (again)
# 	cfff9863d3f8b51b85d42fced60ae9f3d373d0e6 Input field gets list of select options from fetched json (currently …
# 229 Adds input form select options from spoofed resource list
# 	e6a3d74bbe2cae27465cbff24d0df472199d3084 Input field gets list of select options from fetched json (currently …
# 	ab529e2121399c2c12e93d46378b23f07c5d20c0 Fixed sinopiaServerSpoof test after rebase from master
# 	dcd6b0d56ae35e439fac2853ca704585d161bf23 Renamed InputTarget to InputResource and add a check for useValuesFro…
# 236 Default value constraint for type Literal
# 	28604dd5ecd06e4f55ec3962d2d8a76ffd0da3be Add Default value for literal spoof to MonographInstance
# 	5466ca89edbe7c9113944a465b35fc5dc8259564 Set default value if there is a default hash in the valueconstrain hash
# 	e25459d676a503c9f009e6a108b94d103b8724ab Add PropType validation
# 	59c451db7fda88cb444e1680bd198c20cb2f22eb Remove console.log
# 237 Adds a Profile button with DropZone to the StartingPoints section
# 	153c58bc827a3c14393a42ffc67cf30f7544d1e2 Adds file drop component to starting points menu using react-dropzone…
# 239 Adds file drop component functionality to starting points menu
# 	b67ebe1ff4babebdb089af443ade534515ee692d Adds file drop component to starting points menu using react-dropzone…
# 240 Default Mandatory Repeatable and Editable values set
# 	54402800d1a589cbbe849e61dcfc0fb3d914dcf2 Default Mandatory Repeatable and Editable values set
# 241 [WIP]Generated QA Api from swagger spec document
# 	70d5ef74b4cd489e0d14e5fdf2e89d09bb4a95f0 Generated QA Api from swagger spec document and define module in webpack
# 246 Redux store to save input from input type literal
# 	b210e3b7004a96634b0f762ed5b6bc4058743c43 Install react-redux and redux via npm
# 	7112c1d3a91c151a3e19db396aa8c27eb9623dff Connect redux store to InputLiteral, and save user data into global r…
# 	045f1d637f83deefe78978943c89c226b115027a Can add items to redux store
# 	4a525ff20e843128683bdfce295291d9781a1337 Moved reducers and actions into new folders and can now list out what…
# 	31630430c3180c838267511d164b22029a9e5792 Remove defaultLiteral value for input type literal
# 	e4a0009e3806b1d8e82eb2dd3d7b683f75cc8f70 Add Mock Redux test and update broken tests from using Local State. U…
# 	fcb94997c7289e1afdbb59d4eeb469fffa206874 ESLINT add to overrides for no-unsupported-features regarding Import …
# 	74239c68754251c3b56b58222c8995419532df86 Update resourcetemplateform test to use Connect(InputLIteral)
# 	27c31d7a50062bbb6027a0d0c6d75f787eedbecc Add Reducer tests
# 	09ac3461ef87cbb4af132691b0549c5e94560d96 add actions tests
# 247  Use swagger-js and local copy of QA apidoc.json to do authority lookup
# 	d0140300468e6ce1a658a243d0ba3bf0d2bd6b92 Use swagger-js and local copy of QA apidoc.json to do authority lookup
# 248 Renames InputResource to InputList and removes isLoading spinner onBlur
# 	2cd1254a7c262d95886830d5b94231c2a47bcf6f Renames InputResource to InputList and removes isLoading spinner onBlur
# 	338ef409dc02ff062fcfc145b9beae566a8f053c Change component name in tests too
# 249 Change input json fetch parsing to use LOC json for lists
# 	f704e7e25cc4866926b2fa45fedafd8a77fd4cf7 Change input json fetch parsing to use LOC json for lists
# 252 Removing spoofed QA list reference files
# 	7fae94bcf2d538ee4d17ccd54a5a7d56c97d2105 Removing spoofed QA list reference files; now fetching directly from …
# 254 Remove item from redux
# 	4234a42ea6d7cf356290f3f4fac8bb57439f0158 Add remove items
# 	cba86441734f19596bf6ddff3aeef0d729f33774 Use combine reduers now
# 	d43f9722653dfc7551c9de54fa341da87e2a54b6 Allow for X on list items to remove item from redux store
# 	4a268cbc3cd39ae06be60493f122d83043471eb5 Reducer tests for REMOVE_ITEMS
# 	3bcab03b932956132b9201e45c1886c072bb7aad InputLiteral remove Items tests
# 255 Update temp variable name to formInfo
# 	0faedb5489ad5d6cdb33247a658ae5e5648bef79 Update temp variable name
# 260 Input list redux
# 	d19019b8e6db06d7777c63977d48eb5f89ef3982 Adds redux support for input list component
# 	b204fa7b2f90d9dd8951634b7761aa0d281ad4bf Use Object.getOwnPropertyDescription for json item loop to avoid secu…
# 262 Input lookup redux
# 	7f6576251415e81b84842e5189a1ba67a938ecff Adds redux support for input lookup component
# 264 Prop types lint
# 	36397e2e42af5d103f7d7d793c1e528c5ee35d28 Removes eslint prop-types as warning; now it should error when it occurs
# 	cdf8431e2dcf79a32c4ff4b92698c34e1986198a Fixes propTypes validations for InputLiteral
# {'startCursor': 'Y3Vyc29yOnYyOpHODkkVTA==', 'hasNextPage': True, 'endCursor': 'Y3Vyc29yOnYyOpHOEFgSgw=='}
# 266 Use propertyURI for react store id
# 	137a0b968bde7fd03a7c7bff6aed0659c2e41b47 Use propertyURI for react store id
# 267 Use correct Object method getOwnPropertyDescriptor
# 	727f7adb81c2b0d7ef34f0a84a7d1ff4992813be Fixed to use correct method and calling correct array to retrieve values
# 268 Remove comments that have now been re written
# 	75c7efba399b1003c6bbbcf0770809eec628e0c8 Remove comments that have now been re written
# 271 Added support for the Redux Chrome and Firefox extensions
# 	023a1fbe4fc58b11176a6e73bfd2d028de64895f Added support in store for the Redux Chrome and Firefox extensions,
# 272 Adds test for mock formData function call
# 	d53f3d6c4f59a3b7c15b708f44d1cae3d217de01 Adds test for mock formData function call
# 273 Generate RDF from ResourceTemplateForm
# 	92c388c902ceaebdd28fecf510a021d9b8f703fb Merge pull request #277 from LD4P/update-prop-error
# 	7a175a5092e3eff2926d5278e0e4931af09ad735 Merge branch 'master' of https://github.com/LD4P/sinopia_editor
# 	3ef808574c12014909e46868e4147865deb1e194 Merge branch 'master' of https://github.com/LD4P/sinopia_editor
# 	ae5be4dd27b9d974780694b9a60fc4cb980423fe RDF reducer with generateRDF action, displays literals and URIs from
# 	ce0b379d79a35b9d0722236a54cdb3aa7c122db9 Fixe eslint errors with prop types and testing errors
# 	e80ffba7cbedbfe6600df2567a40ecabe4dfa8db Fixes for eslint errors
# 274 Set default values for InputList component if they exist
# 	1e554e78dd1a124790c5e989f2fe01001591fc25 Set default values for InputList component if they exist
# 276 Fix input bug
# 	bf185bc348b2db97929596ae96d6c9ca847710a1 Ensure that each input literal field has a unique id and retains focu…
# 277 Update Proptype id
# 	effdf8508103719a2854d09e08637b7a0a956455 Update Proptype id
# 279 [WIP]Select language for input type literals, defaults to English
# 	656a9dbffeae077ea9ec8b78f0994477ab9a060c WIP language, is a button now and brings up a modal
# 	82ba02f329ac71967840db20f715d3361b51b2c6 create new lang reducer for name space reasons, also languages are no…
# 	21f5f56ce9fe99467c77a55e2055326b47bf3912 Added tests
# 	f13081ebd1610ba0bbec1c5f843f94a44e3b8eaf Comment out REDUX DEVTOOL - need to access redux store in Componenent…
# 	da088292bc09f4686668d22ef8198bd13d729264 Add Reducer tests
# 	6219ec1ed7d63ccb28838b4aed3a7e0161f51383 Add action tests
# 	60742469de79eccdc5ddfad5dd6d2e1863a9fcc2 Fix Proptype errors
# 	4ed54d68fdc7f4fb01072ddc2ae13b0a42680bf1 update store.js comment to add debugging
# 	c14db4dd00457ec8247f25ba4819d7ba15573e0c WIP language, is a button now and brings up a modal
# 	c2ad9f7bb664dfa47ebd790c93d416a15e5a71d5 create new lang reducer for name space reasons, also languages are no…
# 	19f7551ddf55efa772303aed74df50bd695a5508 Added tests
# 	71d053a2b91ed1e8749b370cfd518b96dbf74b6a Comment out REDUX DEVTOOL - need to access redux store in Componenent…
# 	4cabd52ce2ac2df95657a72479a2fcd4fabd6343 Add Reducer tests
# 	2fa66edffbb6df2b2ae444bf3a2baba05183f1b4 Add action tests
# 	c812a9166655444fa26c137c2333bd135fd4a919 Fix Proptype errors
# 	a35f29ca3fcaaa5da4015c0c65751b5378643956 update store.js comment to add debugging
# 	a6fed60eada0aa05658f9e339d7cc8633613388c Merge branch 'rebase-langauges' of https://github.com/LD4P/sinopia_ed…
# 	609e3860aa09deed90c5ba6c70bca4ad019e3b4c Able to add a language item when there are no language items yet
# 	b887342b6f324dd6a3a3645c3d78443f97b23f99 Handle the show/close events, a bit of formatting, and move TODO comm…
# 	f0b8ba1240a0dc82600e60d631ba922148167388 Adds required resource template id to test expectations
# 	d0442f5a1d231641cdf121dafed6f21fc4174759 Add required props to ResourceTemplateForm tests
# 	0beff68f2ce2b8c4534652000bd54b461768c384 Merge branch 'master' into rebase-langauges
# 286 Use a json config doc to match template uris to component and connection details
# 	84cc007ae81d878da449c9b33bf7c2ed60d507d9 Select input components and pass connection details as props based on…
# 296 Editor.jsx: update heading to be closer to what we eventually want
# 	0851c99d1dd814b4b99cadde1f81d5a975a165ab Editor.jsx: update heading to be closer to what we eventually want
# 299 Link text and Styles Changes in Header
# 	f691c9adf2888ca9ce64eb7b6b044bd93a6548a7 Changes Header for Landing Page and Editor Home pages based on
# 300 [WIP]RDF Reducer: Refactor and use N3 Store
# 	7123328feaa4df81ffd53de82060840d17c14568 Refactor rdf reducer,  add RDF display modal, and modify tests
# 	2a314fb396a788bec7149222d9554aaae35e9eaa Fix PropType validations
# 302 BFF does JSON schema validation of resource template on import
# 	067f3cc26bc68e359fb8f8bcef356bbdf2cef908 add package ajv for json schema validation
# 	1b390bcb742eaf7e1888a7e088fb5cfe1a7a70f7 schema validation of resourceTemplates upon loading in starting points
# 	ac5955d97e6747c8a943df351912e9de35c4b866 schemaValidation unit test (need integration tests - see #301)
# 304 Start of integration testing for Linked Data Editor
# 	33bac692b584b8115709bd123e82e87e3425a01d Start of integration testing for Linked Data Editor, tests Landing Pa…
# 	5a910448ea6e1e71b0b6823c96d293c93b1fdc36 moved expect-puppeteer to devDependancies
# 305 [WIP]Adds tests, reducer+action, and modal for displaying generated json-ld
# 	e6ad6e4625c0f2c65a006d887f69e48c151311c9 Adds tests, reducer+action, and modal for displaying generated json-l…
# 	7eefd85ea0353c7b7e44afd5a7e049da13860ed7 Removes extraneous main entities from being added to graph
# 306 Displays a FontAwesome Asterisk when a Property is Mandatory
# 	648a4d42cff0af1ce215e62f585fe01d8bdadc33 Displays a FontAwesome Asterisk when a property is mandatory for Inpu…
# 	fbe027a4622bdbcc102935c279198ea33e51176c Following Naomi suggestions on reducing DIY in codebase, created new
# 312 Update circleci with AWS deploy information
# 	d833307644aa4af4ea35acf2b2b44ee2edc028d5 Update circleci with AWS deploy information
# 314 Delete bfe files
# 	3392af23ec3c977a3252db8f984f10ecdbd27949 Delete bfe files
# 318 PropertyRemark Component
# 	ec9087e40053848601bf29b1b1ae39eb118e8d70 Adds a PropertyRemark component that is used to link to an external U…
# 	4d05b60c7ef7164d27bf6f107354ff7b1ef1e494 The wrapping label's title attribute now set to the propertyTemplate.…
# 319 Displaying generated json-ld and handle switching resource templates
# 	e7492fa5ca06329337ea72841836af437e365fa5 Adds reducer+action, modal, and tests for displaying generated json-l…
# 	f0089d976a55f2d89556f0364be506fa747fce65 Add check for existing resourceTemplateId state in Editor component
# 	36bb368120015adb08d23d5eb402b893961dacee Do not need to import Link module for StartingPoints test
# 	6b767ea3223e9d1aed5eadf94d35e943a930c97d Test for when the Editor component updates with a new resource template
# 	0e079e7dfe8d672d0aec66c2339b938842fefc64 Adds a fixture file for a bibframe Note that is wrapped in a Profile …
# 	97fdd36e9f3b992e5b4abb73041e9a81484f2781 Pass property uri associated with modal through modal button generati…
# 	0b501dd982ae00bd543716dc2b3608539c56bdb7 fix propType validations
# 	2ebd6be4922a5236a52e3c95f3a20aed5d835184 Merge branch 'master' into rdf-integration
# 	f3db8e4db1adb2be8ab155e2bb40790ab436a154 up eslint max warn
# 	fc1555d815ac81afa09fd9f265f8c333d385f43d decrease eslint max warn
# 320 Editor unit tests: beefed up a wee bit
# 	16123f3cc50e94368870a9609b3950e23e1a32dd Editor unit tests: beefed up a wee bit
# 327 Displaying generated json-ld and handle switching resource templates
# 	30f49b0d1940a15e9c103aacdbe0307c54a5174c Adds reducer+action, modal, and tests for displaying generated json-l…
# 328 Adds the ability to select a language for a Literal
# 	d5cc496bf4e29492c748e721780436e6e12d634a Adds the abilty to select a language for a Literal item from a list o…
# 329 Enable cors mode to be able to fetch list from LOC
# 	381ac263df5afc170d45c662d0fe17e34fe0065c Enable cors mode to be able to fetch list from LOC
# 330 Try https for LOC List fetch
# 	024d53d34361a7926bfebe41a531b6cc84231046 Try https for LOC List fetch
# 331 reset component
# 	0ba6ba3344fabb2e6dcbb632e848965abe1db783 reset component
# 	9dcd49e98fa8f7c8290f0130e8119d91aedb4bb9 Fix broken file
# 332 Troubleshoot cors
# 	a9352a3e69587d151995de666cbc5381682bece3 change lookupconfig to match
# 	78d50cef3516347017be92ab5bb41ea41fa4a586 fix test
# 334 LOC uris for List components need to be https to avoid mixed content errors
# 	ab1f9b039a7ab86925e4befc45942b0592905442 Use https for all LOC uris
# 	ff88399012bf0586b5107de93ef2a02645d42fac Fix uri for LOC encoding level
# 335 Remove LoC code and docs we're not using
# 	b3f95284f8cfb1e59a45a94440713611bf8ef0de remove more bfe code
# 	e5f0dae920ff3460d082944f944a0b83a0a1e596 remove bfe specific docs
# 	f6c98b6328b0f0837c77e888b1135c4ac308477b remove unused static/js/* from bfe
# 	0162eb4625fefc1f96aff568a8600c4788bdc7c7 remove unused static/ jsonld-vis.css and favicon.ico orig from bfe
# 	6ac157397ad5bd92c6f55640075176a10f36b588 remove unused static/v1.json orig from bfe
# 336 Adds the default literal value if it exists
# 	15e846b7cd94496b912ff4c03c224bf9601517bb Adds the default literal value if it exists
# 	04ea9efb6fc243593a90ef0ff5ababb2e2c2df16 Adds a default literal to a resource template that renders a modal so…
# 	67f486db1461c218362679f06ed4d40237034b2a No need to declare variable before setting it in try block
# 337 get schema url from within resourceTemplate / profile
# 	fce3905cd5da3a057d8c5d8b8cf7efd38b4cd95b add fixtures for schema validation integration tests
# 	877c5e17a6b32a293857cf938e581ea3c5f75ebe schemaValidate integration test added
# 	0754c1542b6e0742ea57fb7c1408b56205674f42 README: fix typo
# 	fbf48382adfad6146c10738453e606440763d7fa delete no-op StartingPoints integration test
# 	2e315c3a22ffc7d2623ee777324a7af2fbba6a75 StartingPoints gets schema url from profile/template and alerts user …
# 	c81baf2fd387d1ce981d862c093892afd79036b6 ResourceTemplate takes profile or resource template
# 	640480aa2798f918b770a7a44c9e291baec9053b StartingPoints component unit test: remove now failing test, add chec…
# 	03ac2b35ad3212a72e86331dfe1079a606cef035 spoofed profiles updated to be v0.1.0 schema valid
# 	58f53f17c8691e88661e89a5c92490c71d484d69 remove unused test fixtures
# 	f64439c6cd5e9f573485fe7d8dae2ec50a270f8f add comments to StartingPoint test without expect statements
# 	91d47bcd3c15feffb192654eccb5d35ccd76bdec StartingPoints: remove console.debug statement
# 340 Adds the ability to select a language for a Literal
# 	55faff564582c892ccbf46dee82daa3b95f59b82 Adds the abilty to select a language for a Literal item from a list o…
# 	c3574c0d2c5b54bff75c697714d5c88a1bbe764c Adds test for showing the InputLang modal
# 342 default schema 0.0.1 for UAT testing
# 	d2fcfc6642c2cb13f185279fb48d84c80a70877a default schema 0.0.1 for UAT testing
# 343 StartingPoints: alert rather than console.log when using default schema url
# 	5d5d50e85ad448dc6b503f44ed7dd2dd8997362c StartingPoints: alert rather than console.log when using default sche…
# 344 update spoofed MonographInstance resourceTemplate to be schemaValid
# 	8b34bf12e363fb998a05bcc882709fd37ecfdf25 update spoofed MonographInstance resourceTemplate to be schemaValid f…
# 350 Support for repeatable=false for InputLiteral
# 	fb61afdc348e6b59cd9d69a7127a8d2faa6ea2b7 InputLiteral is disabled if there is one item and the property repeat…
# 	8cbea79db1c20aa4e34fa81363f3cb475f58a74a Added test for InputLiteral when repeatable is false
# 353 Little tweaks
# 	f080420801211edb8d4c0336e84113b094d385b1 add class comments to 3 editor components
# 	a9cc8298dcb04206ecc1de9f6e22ad3e63a749cd InputLiteral.test: improve one test description
# 	e2524a36a32a9d0031d5ff8fe3bfe7a07a2fa0a4 package.json:  test scripts don't spew console messages except test-v…
# 	57f83a9517628d3792fd65d2f6deb2d273400482 remove extra blank line
# 	3acf83d35b390ad80659e0152b75303439007aef remove unnec bind statements from constructor
# 	42e6735e480a09d747d1202230cb644f81dd82e7 InputLiteral unit test: move tests inside outer block
# 354 InputLiteral initially disabled when defaults are present and repeatable is false
# 	a8c4d403247db14ad6fca4d07054867e0d9734f8 Adds missing functionality discovered by UAT, input should be disabled
# 356 Default values and entered values on ResourceTemplateForm, styled
# 	b763a014383d123e421bdfe621d8a9bca8c10104 Change key for uri in literal store to be 'uri'
# 	b6d6436fd939fa0536c607d3f1d1465b17b98640 1) Send id for button around through the modals and back to ResourceT…
# 	e455f8f3913bb6ac1279bd5746a228cb1dd8036b Adds PropType validations
# 	1388055594053f5bb1349cca04379605cabae0f6 Modify tests for callback function calls from InputLiteral to Resourc…
# 	2226ac7f4d6d33047f18dbc18e0c2c36eee557b5 Add and fix PropTYpe validations
# 	9d2c8b825857a4c6c3c3bc3543c2824c162399b6 Fix function assignment after rebase; rename notRepeatable function f…
# 359 Remove content for resource (modal) from store and main form
# 	4f6bfe00bc55f0ab454167aa35c684d386fb1cb4 Add reducer to remocve all content for a formData id
# 	7bc5da4eba16491e8b1031dc4917d6a5a9435c53 Display all content values on value button; Add a function to call th…
# 	4fe9befed2ce59637a281ad95df42ba26e141d7e Rename function to handleItemClick for better clarity
# 	c976895268c2122022f3d5eeeaf92b356ad35e26 Adds test for removing formData content from redux and adds proptype …
# 	27e95c8c895b4ca95684390436396951dc8604a9 Rebase from master
# 360 Make sure reducer for literal matches on formData object id
# 	262b1fe93cfd4d5c3225f44c1c08010bd4d70940 Make sure reducer for literal matches on formData object id
# 362 remove wikimedian news bullet
# 	20d103a74b28ae55c64969eb4fb81276f322d8e6 remove wikimedian news bullet
# 363 When setting default literal values, make sure to increment last id
# 	83c665f4f8beb1417802a884c8d0cc3d8b675207 When setting default literal values, make sure to increment the lastI…
# 	0741748afc896c4e41ab439e7611a18af853b8e7 Add test that mocks increment of lastId variable
# 364 Tabstubs 113
# 	5aadb3be7050f235d7c31efdda63f27436d7c7d5 Adding tabs with some styling and components
# 	48ce342b31cf6a1f65244ba514b78aff114552ae adding navlinks to enable route-based tab highlight
# 	e6c0f963926561c185a5b5566664e067cfbede2e adding tests for browse,import tab stubs and navtabs in header
# 	d9f8919ce9ef5aa6125998b00deca1d945b4df92 Merge branch 'master' into tabstubs_113
# 	1ecec4946cca0514b2966389e3ad13ba7cc15db9 updating copyright dates for newer test files
# 366 Template loading defaults
# 	45af80b9e2b2e7d14e542147931fcdfb2dfac5be Fix problem where defaults do not load when a profile is imported.
# 368 Dedupe defaults
# 	e3f3d5289c2f8995581a9128e98696a55c88213c Use Lodash to check whether something exists in the store before addi…
# 369 Version for Milestone 2
# 	010ffec4176b3ce3f050711c9e250f54a489d2fe Version for Milestone 2
# 370 StartingPoints: remove commented out code no longer used
# 	189eb1e91b6811ade1c79dbd4ce4cb904556baa0 StartingPoints: remove commented out code no longer used
# 371 event-stream has an unsafe dependency flatmap-stream
# 	6e8d820e1f57fe19628edac9f77aef8bc002465a Security alert from Github, event-stream has an unsafe dependency fla…
# 375 Testing Chinese Characters in InputLiteral
# 	91c36c0eada116c1ed87b334c2b522821fa7344f Testing Chinese Characters in InputLiteral
# 377 UI Implementation and Redux Store Changes
# 	9f8423357d7e78a51ab3cc090cab5175dd212f7a Started refactoring of Redux store
# 	f1ab4292a353138f589bc144d3c58745860cd42f Resource Templates now in Redux
# 	9c9d64e7085e7f1b7ac198d8be24ed277efd8c29 resourceTemplateSelector, propertySelector, and getProperty functions…
# 	af9e913af767034992938316ae306d0e2daa0840 New PropertyPanel now works on all propertyTemplates, removed
# 	0b490550caea5a75d3d38491b72ba6f25e06089d ResourceTemplate state now hashes ResourceTemplates as a property,
# 	1f793607174f55b4427c712aa060d839ffe4dfc5 Displays first level of resource template properties in a collapse
# 	92c0d8119deec514225a123d24907f229f7069a3 Resource Template property panels now pulling right or left to
# 	8e1b3059b575ce26b42e818124d1663a1410ec62 Initial creation of Property Outline
# 	c0645d8859c92c02534ae2d712d3761f498fadd0 Moved Mint URI Button
# 	d294a8de5b2aed6318537a04167965101ff41f40 Added testing stub modules.
# 	5c58bce9c59c93bae5259828e0bd060c8d79d8cc Started refactoring of Redux store
# 	fa5e7f1d7dbe255c3e0e6ceca310aaa0ec9a2c88 Resource Templates now in Redux
# 	b83c607de8eb43de9b815e6b3c8cd2cf6aa89aad resourceTemplateSelector, propertySelector, and getProperty functions…
# 	dac26d266058d0804426883df18ea81ebe437ff8 New PropertyPanel now works on all propertyTemplates, removed
# 	82039487759439bfc6b7450a50b7557ff7294d71 ResourceTemplate state now hashes ResourceTemplates as a property,
# 	9e037d3ba1a8c30b1a6526298be055af73ea1657 Displays first level of resource template properties in a collapse
# 	faa8d4c12c54624c38d0fe07421557604b2c247e Resource Template property panels now pulling right or left to
# 	d1acb22adf4cd2b3fba8fa14975ddd751c13c1a0 Initial creation of Property Outline
# 	7d015f56f0f7ac985e523be600242cc6877165c7 Moved Mint URI Button
# 	b77ad4a626393492718b3953307a7fced54e0e24 Testing React OutlineHeader, PropertyPanel, and PropertyResourceTempl…
# 	6cfa31f9d0a8bc2e1a1467d29f17880f1e91b1db New PropertyTypeRow component with tests
# 	6e99cd63a050ce0f29b96477d5ac602dbe781d5d Started adding InputLiteral to PropertyResourceTemplates
# 	279636e491453d65f3416575bc10d506729c6512 Implementing React Context for passing ResourceTemplate's id through …
# 	defb3af0f4f68ed6d3a9e965e1dd11974c14c42b Fixes errors resulting from rebase, collapse/expanding now work
# 	f5bd7a64853a82775b178c2e4ecd2a7f17e1e79b Rought support for Resource Templates within the Property Outline UI,…
# 	2ad99902f914f243d6d3d7671eb9806c3dbdd2d1 Passing unit tests
# 	a350240282381bb4e6300aa4339a89e98c3039a9 Decomposing components
# 	08777baebe594fd0982d5afbb4245c4a637c55d9 Linter passing and commented out failing integration test
# 	06f5be7c744e2fcaeb16bfaad8d5e874cf36dbf3 Updating tests based on feedback
# ...
# 970 Fix bad tests
# 	f6088924b1467ff999741c3a8d731434fbe1255e Fix bad tests
# 972 Remove dead code: retrieveFinished()
# 	a525cae6cd8006ddccb08966ecdcc445ab527422 Remove dead code: retrieveFinished()
# 974 Patch version 0.3.4
# 	6f803c1448489fbe5ebab6dc38891f4f374b8ad2 Patch version 0.3.4
# 975 Moves resource template summaries to redux state and loading to a thunk.
# 	293fa1603de569e37a2772a750b81997e7cc23b6 Moves resource template summaries to redux state and loading to a thunk.
# 976 Add search tab to editor
# 	fa95eda912556f36497e47953c0306442fec3df8 Setup search field per #583
# 	36058be52015e92cfda75f6c6fa9ab9ab22c4ba8 Remove unused bits
# 	5d79508818032fde77b27a276293f0c858c25228 Add actions for search started and finished
# 	bcb83a9df6bfa929ac35c76288df2b545bc5fac0 Add initial search results page and handle input on form
# 	78d07f5cd3b5de0f0c31855ff6fa027177fce160 Dispatch SEARCH_STARTED
# 	d42cb2149a111733f904a67ccfa661334af56490 Send query to elasticsearch
# 	9c6ab43bab7975f4545a3d6d3873ee34bbc22f54 Add search results to the redux state
# 	9f083cb7550313c9704265466aad034564f62486 Refactor searchResults into individual actionCreator
# 	98f58972a44f5f984b88cf9b66719b223762bc43 Rebase removing actionCreators
# 	9b1d367cc3ae1292da9420b782ad9bcae00da971 Display search results on the page
# 	dab355b33a2f421e4736913534d711a2fc557f99 Move search code into search tab
# 	8e437e227d41d8ce66378a5478f15943d88bca0d Simplify search to avoid unnecessary actions
# 	e131dc1c60fe579995bcd8203b84251e0bc3fec9 Load resource when clicked
# 	570ad03a0637d943110eb9e7baef3a25f320f71f Remove crufty comment
# 	1e9d38cdae61516752c44ff26e9bb188f81617ad Remove unwritten test
# 	8a9836cab1cd4749bd54496972a274faf882c991 Add subtitle to search query
# 	2b9ccf5ceb2f2136dd8b671e201bfbbdf7e2c782 Remove legacy Browse tab and associated code
# 	b57a1d88706546716dfa4a07582322b76ac0aedf Set warnings to 5
# 977 Redirect to the editor after loading a resource
# 	e5217f2be7e04f9747af16491a06fe377a4d1630 Redirect to the editor after loading a resource
# 978 Sets correct container when saving rdf.
# 	1f621c4ac7657dfa7edb4a8288b1ca126d7aeca1 Sets correct container when saving rdf.
# 980 Convert stubResource to a thunk
# 	dbfed6c0527b5670f7cdcb43ba5df10227df0a43 Convert stubResource to a thunk
# 982 Adds Tagged Release Checklist Github Issue Template
# 	709938bb9362971c32c546a6cb5bd01beea4ee12 Update issue templates
# 	27d7c7145a1123eee8f0c99898ebf39f9a5d9c7a Updated README to match issue template
# 	d029d71901b090a91eec5272afa4c772c6f86de5 Update tagged-release.md
# 984 Loading an existing resource sets the resource URI
# 	50e15cc3c26f7dbbd807d8f9a02f1b3a2bd48cc0 Loading an existing resource sets the resource URI
# 985 Add tls and net to the webpack node config so that request can be used
# 	c88b1029dd09a69c5e3c048ebb31e14d2c63e9ce Add tls and net to the webpack node config so that request can be used
# 986 allow a user to enter a literal on InputQA
# 	bd1a07014979059f6ba6b89fda3228cb426b37d0 allow user to enter a literal
# 987 Clear errors when loading a resource template
# 	b7be11a45814e5f13b0eaefa33af22663d084af0 Clear errors when loading a resource template
# 988 Upgrade to node 12.6
# 	9ea652752bd397f3ef0ea1edda8d3d51b6f3a201 Upgrade to node 12.6
# 989 Use the URL from the stdlib
# 	4bb7662c94eea696fdc59ffe067c7d9e42002e3e Use the URL from the stdlib
# 990 Add a repository to the package.json
# 	6a4744ccb15387d31080a75e6fb0799979af9ec3 Add a repository to the package.json
# 992 Remove static analysis tool
# 	6d61fa7b8c5c298a2fabc8f6b8e54d6befc6cde3 Remove static analysis tool
# 994 Fixes loading of existing resources to use correct resource template.
# 	a457bb8bfe375a0fff928413b3038c6047fd5749 Fixes loading of existing resources.
# 995 Adds option for new uri to InputLookupQA.
# 	4dd1f4d41192c0bf51fc989e49bdc0b7b8944e8b Adds option for new uri to InputLookupQA.
# 	5a46d3b67aeba309527dc9bcc5951d08a1dd0b20 use sensible values in InputLookupQA test
# 	095e7db119317dba541665336eecf3780f9462a6 add tests for custom URI menu rendering
# 	875716c8601a200921ab5723e7cb71fd83087419 require valid URIs to be entered in InputLookupQA; add tests for this
# 996 Remove unused code
# 	d05b489a3b96274743aa95d67159a37257b59628 Remove unused code "removeAllContent"
# 997 Remove unnecessary properties
# 	01ffc308bcdbe860bfb9b0c2af313ef9b16763cd Remove unnecessary properties
# 998 mapStateToProps does not need to return reduxPath, it's a passed in prop
# 	75a2abc52f03a2b9b576b200cb15d7063c887357 mapStateToProps does not need to return reduxPath, it's a passed in prop
# 999 Rename actions to better describe the action the user took
# 	617f1d0e1b364eea9aad8c2ba2f1d2e45f538172 Rename actions to better describe the action the user took
# 1000 Passing uri to setItems is unnecessary
# 	4b66eae801a98f750beb86b105455a4f1d41f6c4 Passing uri to setItems is unnecessary
# 1002 Provide a sensible default for Config.searchHost
# 	806c8d65563f32b38e298758e7e147301397a921 Provide a sensible default for Config.searchHost
# 1003 Extract LanguageButton from InputLiteral
# 	34041811411f3996f9e5eda6e1ecc72c060a6380 Extract LanguageButton from InputLiteral
# 	082aea600e95f1bc24350dd55ef199524ee9fc9e Use redux
# 1004 Links tokens in InputLookupQA component.
# 	ba6fde6b5bcf1ae1dcad4af257926338af4e3c31 Links tokens in InputLookupQA component.
# 1005 Simplify the representation of a language tag
# 	bbe46d8ca4cebbefc7e6adfe04069fb7328e14f7 Simplify the representation of a language tag
# 1008 Clarify link to regular github issues in the issue template
# 	128dd826c00ecc69516945574c9ac86efd69e2c6 Clarify link to regular github issues in the issue template
# 1009 Update language
# 	6851ac497c1211df9360590493cdc5748f4f5742 Update language
# 1011 Extract the reducers related to entities to a separate file
# 	264fc3909d0641388f5f3da1c4d24ab29dc30f23 Extract the reducers related to entities to a separate file
# 1012 Load the language data once into entities
# 	82689db65d1b938aed46ea535e0a0204205b84f4 Add copyright
# 	f2ba6b8c7aa1c278a159cad4d150ab6eb2f69be3 Load the language data once into entities
# 1013 Extract the reducer related to search into a separate file
# 	441aacfe59a0b6a90afae05161320f9773ea1118 Move search reducer into seperate file'
# 1016 Load the languages when the editor form is drawn
# 	8cee814fa29b370ef80d68a7d6eadfa96949b113 Load the languages when the editor form is drawn
# 1017 Update ResourceStateBuilder to build the simpler language
# 	301a853f6c44b3c80a49ef79534791f4bb29ce3c Update ResourceStateBuilder to build the simpler language
# 1019 Update issue templates
# 	b190efb81d22fcf441313dc91dc4fcf70adfbee4 Update issue templates
# 1020 Get rid of items in redux state
# 	a3c07655262532acd8fe9c563a76f6ebb93d5e59 bad redux path
# 1021 Adds recursive validation. Fixes display of validation errors.
# 	7c437a130a8abdffeaf9854e3e3b555662737928 Adds recursive validation.
# 1023 Integrating context and discogs typeaheads
# 	b232c8e4c8483a0439340584a749ae3c543757c3 starting context component
# 	e5a0b55078fa1f79b25fb1e58f20007f74ff571d Merge branch 'master' into lookup_context
# 	7e16ecfb745723372f458403d0a02b583c8d8234 Merge branch 'master' into lookup_context
# 	22c2595566147c847c69ca5cc5c12b7913fbbb78 adding context example using latest
# 	c98d1f21027bec0f6a8a15314321b59129da1a16 Merge branch 'master' into lookup_context
# 	7baefc88bcccf3316cd1905edf2c5159d108c6de adding sharevde test example
# 	f00a904c0ccd6b265115bc19ed069c6b4cd32050 updating selection and saving
# 	660bd80a0da2ebacb4a0f2203ad2ca9a688f18fa selection and removal tied in
# 	326f97af7627a957677d0c7952e555de196b3a3d merging in changes from master
# 	96dc130c898d55c6e85fa6d36c0298424f474469 funneling to different rendering
# 	d19b3cabd508a8b9a0a973076f92fbc0f3d336ec adding subtype to trigger context or autocomplete
# 	401f704f0decb1fb67f75ef1b0809af2545e939e integrating discogs context typeahead
# 	f8d8dc936d726978b5d9dc2d0315b45d5940b4a6 ordering for lcnaf person and organization
# 	9a4377378ccd403eb94814076146952ef8e91a0b eslint updates
# 	1259e1f14ce165df0b3aacfd22e0a44b422daa00 adding wikidata example
# 	96a4fb2659cbde93a3961d9fa4340ceb6a7f5548 merging in latest from master
# 	effe0474fdd69fbcef096c28b9b798a0c14fd0bc some refactoring, more to come
# 	8039889589c0e3545e2cddde922bdca0277b6198 adding loading icon
# 	fb5c165ebf72b2e054088453eefb654f038660f6 additional changes
# 	c3a06b5236a932249d55296596608dd647c639fd merging from master, refactoring search to allow different input comp…
# 	8294e9eaa408ab43ebce305aec08111ae73328d7 some refactoring, with combining discogs and typeahead into one compo…
# 	072e465c7dcdbe9ffc5ca02444d4e776a44f7ff6 merging latest in from master, updating error handling for context
# 	aabace5c40062bbb9ea74dbb5352ec28d64ce9b4 typeahead warnings and errors
# 	207f7d6aa7f48ce01580a10e569fba9fab975231 getting in literal changes as well
# 	7e0de98f4532eef5802cb939f1777e627925bea9 working through warnings
# 	f99cb6b8aa09a32551469af4e8c56e7b7b6ffa7d pulling out styles into css
# 	7d7dd83a4f7dfe64b1de356cfa1dc876c20c8127 removing local file that shouldn't be in the branch
# 	1c2e013eea2ae3513679a5c955656c9bbe61945e integrating latest from master
# 1026 Switch to using shortid for lang id to avoid blank or missing default…
# 	e3035a135d3fe557b67119c06b394416ee4d862a Switch to using shortid for lang id to avoid blank or missing default…
# 1027 Clears the resourceURIMessage when clicking back into the editor screen
# 	51190a90411215929818452aea497dff6d457899 Add an action create to clear the resource URI message
# 	386bdd8a8abf2b5242ff7ee76cb73dd78cd7b05e Remove comment cruft
# 	704dffb58dc939eaddaf606101f7c6c77507a9bd Mock function in test
# 	c36f8423a00d9163c1755d20c3303a61304e5a37 Add test for clearing resource URI message
# 	006f2f5e7a6fe11063871126e6d4ccc6fff05c56 Undo changes to package-lock.json
# 	39f0cbc7c369d1ae45e8e28ed843f56c5c07541d Remove unnecessary action creator
# 	a568e2d78c46ca5e1aa051a2f31b061fec569341 Rewrite testing
# 1028 Correctly handles nested properties that are mandatory and have defau…
# 	d7d38b3df4901ba669c5345c3f1599fc8a23369a Correctly handles nested properties that are mandatory and have defau…
# 1029 Add default sorting to the sinopia resource templates table
# 	3a2e8dd92a08b96d7fc1363e9402c78bd5bafa6c Add default sorting to the sinopia resource templates table
# 	1d3aa50fa7809aca9b897cf13f4f8eccdbc18cb6 Fixes #847 - word wrapping
# 1030 wrap all columns in resource template table
# 	03b23ad8478ed6977e0c20335ea29639745b7c2e wrap all columns in resource template table
# 1031 add date field to resource template table
# 	d1378efffd078bfd0119dd590fcda98780a7ddc1 add date field to resource template table
# 1034 Fixed actionCreators/resources test.
# 	5050a7883cb5d68b75870109ad8f63f3573d3385 Fixed actionCreators/resources test.
# 1038 Oops, adds validation error display to InputURI.
# 	34c9bea967331f9e9c65f6aca02c5cd54a3fc52e Oops, adds validation error display to InputURI.
# 1041 Patch Release 0.3.5
# 	1a1175be39669a2ea541499a01837a3e89b991bd Patch 0.3.5 along with Release notes
# 1042 Changle tab text to "Load RDF"
# 	e23a47b28b8c7e0a9454632b55a071f5d909e8cf Fixes #1037
# 	f6e47f0c75c6f8131ef271ed02f4f9e005beb7d7 Update integration test
# 1043 Use the correct authority for MESH
# 	cb2969f0f6c728ec21efbb610dc8fe7608033688 use the correct authority for MESH
# 1046  Adds add/remove functionality to properties of root resource template.
# 	2de97fd7e91c7edbf0cf3c39f1e68653c2a37999 Adds add/remove buttons to property panels.
# 1050 Adds error message when user enters a literal in InputURI.
# 	838d695acad1342c72ba58fdb2d48e320a67848e Adds error message when user enters a literal in InputURI.
# 1052 Adds notification when saving and publishing a resource.
# 	30e751ca0391a8f5012143e7c710706dc94feae7 Adds notification when saving and publishing a resource.
# 1053 Reload the resource tempaltes summaries after import
# 	6816e1dd2f90ef1e2cb12015c428f20259ab2912 Reload the resource tempaltes summaries after import
# 1054 Also validates when adding / removing properties.
# 	a09e9a0052f54336dd51f525cfb272ebf5c0594f Also validates when adding / removing properties.
# 	22627b9ba61097cfc4d7f05d6c640244c9d03e27 Added additional waits to literalPropertyTemplates.test.js
# 1056 adjust css style of component to make react happy
# 	1c28af0a31739420a76d819445708294d52c53e1 adjust css style of component to make react happy
# 1057 Allows literal in InputLookupQA.
# 	355971ef49e4a454e36077459bd6bd0105bdbe8f Allows literal in InputLookupQA.
# 1058 Update NewsItem.jsx
# 	ada3213e56c46b26a8e4e773fb1961621d7c8775 Update NewsItem.jsx
# 1061 Patch 0.3.6 along with Release notes
# 	4bb3762e6b057c4a485229aa045e4d8e5afc2e73 Patch 0.3.6 along with Release notes
# 1062 Set SEARCH_HOST in circle so it is available in the build
# 	aad799c3c1eac040ef790fef3ba66312d78dc9a8 Debugging search in dev
# 1063 Follow up on search URL
# 	08b9291bab14c1ac8725899f18e51ba5a4fe62c9 Add to webpack
# 1064 Fix docker build command
# 	0ea641d687dc21ed4de4f57cf62a60d8010c5800 Fix docker build command
# 1066 Patch 0.3.7 with release notes
# 	4598d2b72f93cb22e6fba3ec3bd2007caa4f123d Patch 0.3.7 with release notes
# 1067 Unsaved resource prompt
# 	972030b24ac3ddd92a4d89fd311ba7df57428ffb Notifies user before discarding unsaved resource. Disables Save butto…
# 	c93f83d1eaffd7f07ab6c0bac4c5cb689980be0c Test tweak
# 1069 Set INDEX_URL into the env so it is available
# 	3ea3a9ced06403bae4ce5f6d6dfff3b7b77ecfb3 Set INDEX_URL into the env so it is available
# 1075 Do not copy the dist and nodmodules into the image
# 	d36d50bf84fe6bcd0a82707a0498f80123e0abd2 Do not copy the dist and nodmodules into the image
# 1076 Changes add buttons to add another.
# 	847e5cb43d12bc72db570d088ba1df0e2f7a2e3a Changes add buttons to add another.
# 1077 Removed duplicate lookups
# 	dc995f042c1452872bbbeb077b2546826415d0a5 Removed duplicate lookups
# 1079 Change keyField to a field that exists on the results
# 	d936e81182a577debb2faa2f69809851889144c4 Change keyField to a field that exists on the results
# 1080 Changes to adding / toggling of properties.
# 	e8104195bbb11c05ff562eeab39f3fe5f9d5d78a Changes to adding / toggling of properties.
# 1081 Use the Button attributes rather than class
# 	f81ec9ea9d1df16148707cab281227a71ceb815c Use the Button attributes rather than class
# 1085 Aligned InputLiteral and InputLookup.
# 	225b62dbf5f4a0b768c1d6e5d32acca1887f3ad8 Aligned InputLiteral and InputLookup.
# 1086 Switches to a right chevron for contracted toggle.
# 	4da9d3d35cb993e29aef334411163cac02f90b45 Switches to a right chevron for contracted toggle.
# 1087 Added + before blue Add button on property panel.
# 	bff119b14179ecb60edaa97f4cc647d0554bd614 Added + before blue Add button on property panel.
# 	c40f80de1e08aba32bc0f012655530f42259384c Test tweak
# 1088 Only render property panel body when it has been added.
# 	9d163fb08af6a4ed18930125cb9158c98e92814d Only render property panel body when it has been added.
# 1090 make "required" asterisk same color as text
# 	470c4e7f28641c73c1309313fda4c50047884a5d required asterisk same color as text
# 1091 Moves property info to icon. Bolds property labels.
# 	d1083c8a90d6d14eda762ebffd9026f677c33534 Moves property info to icon. Bolds property labels.
# 	b11b6b9730e0eee92566e2cd42f9c7915cb17635 Tweak to integration test.
# 1093 Fixes PropType for current user for SaveAndPublishButton.
# 	ca9a1fa66357c25c66d3e218e217b36f7e98e5d6 Fixes PropType for current user for SaveAndPublishButton.
# 1094 Simplify LanguageButton
# 	6ebf65c9d322698133f30e6834ae7f9c795d81ba Simplify LanguageButton
# 1095 Patch 0.3.8
# 	2a46835481b4d05e71ac0f36de1aaf5f7e31ae26 Additional steps in Tagged Release template
# 	c3a11ef20565a4991ffa5d32c2d722eff4f3dab3 Tagged version 0.3.8
# 1096 Remove language label from the resource state
# 	38c871522670c2219c5d23031e4030a9fb0d7b37 Remove language label from the resource state
# 1097 Remove unnecessary property formData from InputLiteral
# 	38fff23bb0b4c2c2c7bf3efe3ec874c51fb99d93 Remove unnecessary property formData from InputLiteral
# 1098 Make the layout responsive.
# 	bc980cdff564410ca1d45de2884d49b4a0a9dc79 Make the layout responsive.
# 1102 Right align the add/remove panel header buttons
# 	91b47ee2351c2f68ef93da52e0ac3ecbb80e7c8e Right align the add/remove panel header buttons

# %%
print(f"{work_cycle_one_commits['metrics']['additions']}")
# Out:
# 232753

# %%
pull_requests[0]['data']['repository']['pullRequests']['edges'][0]
# Out:
# {'node': {'closedAt': '2018-09-26T22:14:43Z',
#   'commits': {'edges': [{'node': {'commit': {'oid': '2125557aa8e65044a9f7fa28349cc4ea1c0a74ca',
#        'additions': 43,
#        'deletions': 42,
#        'committedDate': '2018-09-26T21:07:23Z',
#        'messageHeadline': 'Gruntfile: reformatted whitespace so tasks line up',
#        'author': {'user': {'login': 'ndushay'},
#         'date': '2018-09-26T14:07:23-07:00'}}}}]},
#   'createdAt': '2018-09-26T21:09:20Z',
#   'mergedAt': '2018-09-26T22:14:43Z',
#   'mergedBy': {'login': 'jermnelson'},
#   'number': 11,
#   'title': 'Gruntfile: reformatted whitespace so tasks line up',
#   'state': 'MERGED'}}

# %%
with open("../data/json/commits-001.json", "w+") as fo:
    json.dump(work_cycle_one_commits, fo, indent=2, sort_keys=True)

# %% [markdown]
# ## Issues for Sinopia Linked Data Editor, Profile Editor, Indexing Pipeline, ACL, and Sinopia Server

# %%
def write_closed_issues(all_closed):
    for i, row in enumerate(all_closed):
        i+=1
        filename = f"../data/json/issues-{i:03}.json"
        with open(filename, "w+") as fo:
            json.dump(row['data']['repository']['issues']['edges'], fo, indent=2, sort_keys=True)

# %%
all_issues = github.all_issues()
write_closed_issues(all_issues)

# %%
def load_issues():
    walk = next(os.walk("../data/json"))
    issues = []
    for filename in walk[2]:
        filepath = f"{walk[0]}/{filename}"
        with open(filepath) as fo:
            result = json.load(fo)
            issues.extend(result)
    df = data.issues_data_frame(issues=issues)
    return df

# %%
all_issues = load_issues()

# %%
print(f"max: {all_issues['elapsed'].max()}, min: {all_issues['elapsed'].min()}, mean: {all_issues['elapsed'].mean()}, median: {all_issues['elapsed'].median()}")

# %%
all_issues.plot()

# %%
closed_issues

# %%
editor_closed_first100.get('message')

# %%
print(closed100_df)
